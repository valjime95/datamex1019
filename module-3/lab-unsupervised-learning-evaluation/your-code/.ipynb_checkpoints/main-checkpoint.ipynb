# %% [markdown]
# # Unsupervised Learning Model Evaluation Lab
#
# Complete the exercises below to solidify your knowledge and understanding of unsupervised learning model evaluation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn import datasets

data = datasets.load_wine()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.Series(data["target"])

# %% [markdown]
# ## 1. Train a KMeans clustering model on the data set using 8 clusters and compute the silhouette score for the model.

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score as ss

kmeans = KMeans(n_clusters = 8)
model8 = kmeans.fit(X)
m8_labels = model8.labels_

#score
ss(X, labels = m8_labels, metric = 'euclidean')
y_pred = model8.predict(X)

# %% [markdown]
# ## 2. Train a KMeans clustering model on the data set using 5 clusters and compute the silhouette score for the model.

# %%
kmeans = KMeans(n_clusters = 5)
model5 = kmeans.fit(X)
m5_labels = model5.labels_

#score
ss(X, labels = m5_labels, metric = 'euclidean')
# Out:
# 0.5489993239795691

# %% [markdown]
# ## 3. Train a KMeans clustering model on the data set using 3 clusters and compute the silhouette score for the model.

# %%
kmeans = KMeans(n_clusters = 3)
model3 = kmeans.fit(X)
m3_labels = model3.labels_

#score
ss(X, labels = m3_labels, metric = 'euclidean')
# Out:
# 0.5711381937868844

# %% [markdown]
# ## 4. Use elbow curve visualizations to see if you can determine the best number of clusters to use.
#
# The Yellowbrick library has 3 metrics that you can plot using the `metric` parameter:
#
# - **distortion**: mean sum of squared distances to centers
# - **silhouette**: mean ratio of intra-cluster and nearest-cluster distance
# - **calinski_harabasz**: ratio of within to between cluster dispersion

# %%
from yellowbrick.cluster import KElbowVisualizer as elbow
model = KMeans()
elbow1 =elbow(model=model, k = (2,10))
elbow1.fit(X);

# %%
model_km = KMeans(n_clusters = 4)
model_km.fit(X)
y_km =model_km.labels_

# %% [markdown]
# ## 5. Try performing the same elbow tests with an AgglomerativeClustering model and compare the results you get to the KMeans results.

# %%
from sklearn.cluster import AgglomerativeClustering as AC

model2 = AC()
elbow2 =elbow(model=model2, k = (2,10))
elbow2.fit(X);

# %%
model_ac = AC(n_clusters = 4, linkage = 'single')
model_ac.fit(X)
y_ac =model_ac.labels_

# %%
from sklearn.metrics import adjusted_rand_score as ars

ars1_ = ars(y, y_km) #kmeans
ars2_ = ars(y, y_ac) #agglomerative clustering
print(ars1_, ars2_)
# Out:
# 0.30314688305894566 0.006628042412302277

# %% [markdown]
# ## 6. Create and plot a scatter matrix showing how the clusters are grouped across all the different combinations of variables in the data.
#
# Use the model and number of clusters that returned the best result above.

# %%
# KMeans model.

import matplotlib.pyplot as plt
import seaborn as sns

X['labels'] = y_km

sns.pairplot(X,hue = 'labels')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %% [markdown]
# ## 7. Apply a PCA transform and plot the first two principle components with the plot point colors determined by cluster.

# %%
from scipy.spatial.transform import Rotation as R
rot = R.from_euler('y', 45, degrees = True)
rot.apply(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-0df59e3df515> in <module>
#       1 from scipy.spatial.transform import Rotation as R
#       2 rot = R.from_euler('y', 45, degrees = True)
# ----> 3 rot.apply(X)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/scipy/spatial/transform/rotation.py in apply(self, vectors, inverse)
#    1286         if vectors.ndim > 2 or vectors.shape[-1] != 3:
#    1287             raise ValueError("Expected input of shape (3,) or (P, 3), "
# -> 1288                              "got {}.".format(vectors.shape))
#    1289
#    1290         single_vector = False
#
# ValueError: Expected input of shape (3,) or (P, 3), got (178, 14).

# %%
pd.unique(y, return_count =True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-0bbb01613788> in <module>
# ----> 1 pd.unique(y, return_count =True)
#
# TypeError: unique() got an unexpected keyword argument 'return_count'

# %% [markdown]
# ## 8. Generate a series of t-SNE plots showing the clusters at a variety of perplexities.
