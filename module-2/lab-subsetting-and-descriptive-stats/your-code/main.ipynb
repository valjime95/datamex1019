# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
temp = pd.read_csv('Temp_States.csv')
temp = pd.DataFrame(temp)

# %% [markdown]
# #### Print `temp`

# %%
print(temp)
# La base de datos consta de siete registros y tres variables.
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
temp.dtypes
# Dos de las variables son categóricas y una de tipo float.
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York

# %%
temp[temp.State=='New York']
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
temp[temp.State=='New York'].mean()
# Out:
# Temperature    10.740741
# dtype: float64

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
temp[temp.Temperature > 15][['City','State']]
# Out:
#        City        State
# 0       NYC     New York
# 3  Hartford  Connecticut
# 5    Treton   New Jersey
# 6    Newark   New Jersey

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
temp[temp.Temperature > 15]['City']
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
temp[(temp.Temperature > 15) & (temp.Temperature < 20)]['City']
# Out:
# 0         NYC
# 3    Hartford
# Name: City, dtype: object

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
print(temp.groupby('State').mean())
print(temp.groupby('State').std())
# Out:
#              Temperature
# State
# Connecticut    15.833333
# New Jersey     21.111111
# New York       10.740741
#              Temperature
# State
# Connecticut     1.964186
# New Jersey      1.571348
# New York        8.133404

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
df = pd.read_csv('employee.csv')
employee = pd.DataFrame(df)
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
employee.dtypes
# Se tienen 7 variables, de las cuales cinco son de tipo categóricos y dos de tipo entero.
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %%
employee.mean()
# Out:
# Years      4.111111
# Salary    48.888889
# dtype: float64

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# %matplotlib inline
employee.hist(bins = 50);

'''
Salario.
Se observa que no tiene una distribución con continua, 4 personas tienen salarios menores a 40, 2 de aprox 55, 1 de 60 y 2 
de 70 aproximadamente.

Años.
Se puede observar una alza en el histograma en el año 2, disminuye en 3 y se queda constante hasta 8 que incrementa
una unidad, esto indica que 3 personas(frecuencia max) han laborado
2 años, mientras existen tres personas que han laborado, 3,4,7 años respectivamente. Por otro lado 
dos personas que han laborado 8 años.
'''
# Se puede observar que el salario se concentra entre dos rangos, menor que cuarenta y un poco menos de 
# cincuenta a
# Out:
# '\nSalario.\nSe observa que no tiene una distribución con continua, 4 personas tienen salarios menores a 40, 2 de aprox 55, 1 de 60 y 2 \nde 70 aproximadamente.\n\nAños.\nSe puede observar una alza en el histograma en el año 2, disminuye en 3 y se queda constante hasta 8 que incrementa\nuna unidad, esto indica que 3 personas(frecuencia max) han laborado\n2 años, mientras existen tres personas que han laborado, 3,4,7 años respectivamente. Por otro lado \ndos personas que han laborado 8 años.\n'

# %% [markdown]
# #### What's the average salary in this company?

# %%
employee.Salary.mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
employee.Salary.max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
employee.Salary.min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
employee[employee.Salary == employee.Salary.min()]['Name']
# Out:
# 1    Maria
# 2    David
# Name: Name, dtype: object

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
employee[employee.Name == 'David']
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
employee[employee.Name == 'David']['Salary']
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
employee[employee.Title == 'associate']
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
employee.iloc[0:3, 0:]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
employee.loc[0:2,['Name','Department','Education','Gender','Title','Years','Salary']]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
employee[(employee.Title == 'associate') & (employee.Salary > 55)]
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
employee.groupby('Years').mean()
# Out:
#           Salary
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %% [markdown]
# ####  What is the average Salary per title?

# %%
employee.groupby('Title').mean()['Salary']
# Out:
# Title
# VP           70.000000
# analyst      32.500000
# associate    56.666667
# Name: Salary, dtype: float64

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
plt.figure(figsize=(15,10))
employee.boxplot();
'''
En el diagrama de caja de la variable años se pude ver que la mediana está muy cerca del primer cuantil, mientras que 
la mediana  de la variable Salario se acerca mucho al tercer cuantil.
Por otro lado, los brazos de la caja de años no se alejan mucho por lo que podemos decir que no hay outliers.
Finalmente para el caso del salario, se puede ver que el brazo superior de la caja es más largo que el brazo inferior, p
sin embargo como se dijo anteriormente la media esta mucho mas cercana a este punto, que al punto mínimo.
'''
# Out:
# '\nEn el diagrama de caja de la variable años se pude ver que la mediana está muy cerca del primer cuantil, mientras que \nla mediana  de la variable Salario se acerca mucho al tercer cuantil.\nPor otro lado, los brazos de la caja de años no se alejan mucho por lo que podemos decir que no hay outliers.\nFinalmente para el caso del salario, se puede ver que el brazo superior de la caja es más largo que el brazo inferior, p\nsin embargo como se dijo anteriormente la media esta mucho mas cercana a este punto, que al punto mínimo.\n'

# %%
employee.quantile(.25)
# Out:
# Years      2.0
# Salary    35.0
# Name: 0.25, dtype: float64

# %%
employee.quantile(.75)
# Out:
# Years      7.0
# Salary    60.0
# Name: 0.75, dtype: float64

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
employee.groupby('Gender')['Salary'].mean()
# El salario sí es diferente por género. Los hombres ganan  en promedio más que las mujeres.
# Out:
# Gender
# F    47.5
# M    50.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
print(employee.groupby('Department').mean()[['Years','Salary']])
print(employee.groupby('Department').min()[['Years','Salary']])
print(employee.groupby('Department').max()[['Years','Salary']])
# Out:
#                Years  Salary
# Department
# HR          4.666667   45.00
# IT          4.500000   48.75
# Sales       2.500000   55.00
#             Years  Salary
# Department
# HR              2      30
# IT              1      30
# Sales           2      55
#             Years  Salary
# Department
# HR              8      70
# IT              8      70
# Sales           3      55

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
orders = pd.read_csv('orders.csv')
orders = pd.DataFrame(orders)

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
orders.dtypes
'''
esta base consta de 14 variables, 2 categóricas (StockCode, Country), 2 de tipo float (amount_spent, UnitPrice)
y 10 de tipo entero ('Unnamed: 0', 'InvoiceNo', 'year', 'month', 'day', 'hour','Description', 'Quantity', 'InvoiceDate', 'CustomerID')
'''
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
orders.describe()
'''
En la siguiente tabla se puede ver un summary de todas las variables numéricas, por lo que podemos ver que la venta maxi
fue de 168,l469.60 mientras que la mínima fue de 0. En promedio, la cantidad gastada fue de 22.39, la desviación estándar
es muy alta debido a que existe una gran variabilidad de los datos.
La media del precio unitatios es de 3.11, siendo el precio unitario mínimo de cero y el máximo de 8,142.75, al parecer
en esta columna los datos también están en un rago muy grande, aunque se podria tomar el valos máximo como un outlier.
'''
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %%
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# ...

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
orders.amount_spent.mean()
# Out:
# 22.39474850474768

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
orders.amount_spent.min()
# Out:
# 0.0

# %%
orders.amount_spent.max()
# Out:
# 168469.60000000001

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
orders[orders.Country == 'Spain']['CustomerID']
# Out:
# 4250      12557
# 4251      12557
# 4252      12557
# 4253      12557
# 4254      12557
# 13974     17097
# 13975     17097
# 13976     17097
# 13977     17097
# 13978     17097
# 13979     17097
# 13980     17097
# 13981     17097
# 13982     17097
# 13983     17097
# 13984     17097
# 13985     17097
# 13986     17097
# 13987     17097
# 13988     17097
# 13989     17097
# 13990     17097
# 13991     17097
# 13992     17097
# 13993     17097
# 13994     17097
# 13995     17097
# 13996     17097
# 13997     17097
# 13998     17097
#           ...
# 394708    17097
# 394709    17097
# 394710    17097
# 394711    17097
# 394712    17097
# 394713    17097
# 394714    17097
# 394715    17097
# 394716    17097
# 394717    17097
# 394718    17097
# 394719    17097
# 394720    17097
# 394721    17097
# 394722    17097
# 394723    17097
# 394724    17097
# 394725    17097
# 394726    17097
# 394727    17097
# 394728    17097
# 394729    17097
# 394730    17097
# 394731    17097
# ...

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
orders[orders.Country == 'Spain'].index.value_counts().sum()
# Out:
# 2485

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
orders[orders.Quantity > 50]['CustomerID']
# Out:
# 46        13748
# 83        15291
# 96        14688
# 102       14688
# 174       16029
# 175       16029
# 176       16029
# 177       16029
# 178       16029
# 179       16029
# 180       16029
# 215       17511
# 217       17511
# 218       17511
# 219       17511
# 222       17511
# 223       17511
# 225       17511
# 231       17511
# 232       17511
# 245       13408
# 246       13408
# 247       13408
# 248       13408
# 376       12791
# 406       14045
# 673       13255
# 718       13694
# 719       13694
# 720       13694
#           ...
# 397113    18102
# 397114    18102
# 397115    18102
# 397116    18102
# 397117    18102
# 397118    18102
# 397119    17949
# 397120    17949
# 397155    13077
# 397330    12433
# 397336    12433
# 397344    12433
# 397351    12433
# 397371    12433
# 397372    12433
# 397380    12433
# 397448    17490
# 397451    16446
# 397454    17389
# 397471    15694
# 397563    12985
# 397572    12985
# 397586    12985
# 397622    17754
# ...

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
orders[(orders.Quantity > 50) & (orders.Country == 'Spain')]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# 174442      248797     558871     22384  2011      7    1    13
# 174443      248798     558871     20727  2011      7    1    13
# ...

# %% [markdown]
# #### Select all free orders

# %%
orders[orders.amount_spent == 0]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
orders.Description[orders.Description.str.startswith('lunch bag')]
# Out:
# 93              lunch bag red retrospot
# 172         lunch bag dolly girl design
# 354         lunch bag dolly girl design
# 359             lunch bag red retrospot
# 360          lunch bag spaceboy design
# 361                  lunch bag woodland
# 362             lunch bag pink polkadot
# 402             lunch bag suki  design
# 403                 lunch bag cars blue
# 404             lunch bag  black skull.
# 532                 lunch bag cars blue
# 533          lunch bag spaceboy design
# 535         lunch bag dolly girl design
# 536             lunch bag suki  design
# 537             lunch bag  black skull.
# 605             lunch bag red retrospot
# 1414         lunch bag spaceboy design
# 1415            lunch bag  black skull.
# 1416            lunch bag suki  design
# 1748            lunch bag  black skull.
# 1758            lunch bag red retrospot
# 1771            lunch bag  black skull.
# 1926            lunch bag pink polkadot
# ...

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
orders.Description[orders.InvoiceDate.str.startswith('2011') & (orders.Description.str.startswith('lunch bag'))]
# Out:
# 26340           lunch bag red retrospot
# 26341                lunch bag woodland
# 26512        lunch bag spaceboy design
# 26513                lunch bag woodland
# 26860           lunch bag pink polkadot
# 26861           lunch bag suki  design
# 26862        lunch bag spaceboy design
# 26863           lunch bag  black skull.
# 26864           lunch bag  black skull.
# 26902           lunch bag red retrospot
# 26903                lunch bag woodland
# 27118           lunch bag pink polkadot
# 27242           lunch bag suki  design
# 27360        lunch bag spaceboy design
# 27361           lunch bag red retrospot
# 27727           lunch bag suki  design
# 27758               lunch bag cars blue
# 27760        lunch bag spaceboy design
# 28100           lunch bag red retrospot
# 28136                lunch bag woodland
# 28137               lunch bag cars blue
# 28138           lunch bag pink polkadot
# 28183               lunch bag cars blue
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
orders[orders.Country == 'Spain']['amount_spent'].hist()

# %% [markdown]
# #### Select all orders made in the month of August

# %%
orders[orders.month == 8]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# 199480      285426     561905     84978  2011      8    1     9
# 199481      285427     561905     21754  2011      8    1     9
# 199482      285428     561905     23226  2011      8    1     9
# 199483      285429     561905     21715  2011      8    1     9
# 199484      285430     561905     21716  2011      8    1     9
# 199485      285431     561905     21746  2011      8    1     9
# 199486      285432     561905     21755  2011      8    1     9
# 199487      285433     561906     22367  2011      8    1    10
# 199488      285434     561906     20914  2011      8    1    10
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# Out:
#                  Unnamed: 0  InvoiceNo  StockCode   year  month    day   hour  \
# Country
# Australia               107        107        107    107    107    107    107
# Austria                  88         88         88     88     88     88     88
# Belgium                 194        194        194    194    194    194    194
# Canada                    5          5          5      5      5      5      5
# Channel Islands         140        140        140    140    140    140    140
# Denmark                  16         16         16     16     16     16     16
# EIRE                    593        593        593    593    593    593    593
# Finland                  61         61         61     61     61     61     61
# France                  569        569        569    569    569    569    569
# Germany                 795        795        795    795    795    795    795
# Iceland                  22         22         22     22     22     22     22
# ...

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
orders.groupby('Country').mean()['amount_spent']
# Out:
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# Poland                   22.226212
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
orders[orders.UnitPrice == orders.UnitPrice.max()]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour Description  \
# 118352      173382     551697      POST  2011      5    2    13     postage
#
#         Quantity          InvoiceDate  UnitPrice  CustomerID         Country  \
# 118352         1  2011-05-03 13:46:00    8142.75       16029  United Kingdom
#
#         amount_spent
# 118352       8142.75

# %%
df_clean.trany[df_clean.trany.str.startswith('Au')]='AUTO'

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
date_ave = orders.groupby('InvoiceDate').mean()['amount_spent']
date_ave
# Out:
# InvoiceDate
# 2010-12-01 08:26:00        19.874286
# 2010-12-01 08:28:00        11.100000
# 2010-12-01 08:34:00        21.798750
# 2010-12-01 08:35:00        17.850000
# 2010-12-01 08:45:00        42.793000
# 2010-12-01 09:00:00       204.000000
# 2010-12-01 09:01:00        11.100000
# 2010-12-01 09:02:00        16.241250
# 2010-12-01 09:09:00       350.400000
# 2010-12-01 09:32:00        32.703333
# 2010-12-01 09:34:00        11.100000
# 2010-12-01 09:37:00        23.420000
# 2010-12-01 09:41:00        13.466111
# 2010-12-01 09:45:00        35.883333
# 2010-12-01 09:53:00        37.661538
# 2010-12-01 09:56:00        18.692857
# 2010-12-01 09:57:00       169.400000
# 2010-12-01 09:58:00       638.784000
# 2010-12-01 09:59:00        16.152857
# 2010-12-01 10:03:00        25.589286
# 2010-12-01 10:19:00        76.072500
# 2010-12-01 10:29:00        31.814000
# 2010-12-01 10:37:00        79.600000
# 2010-12-01 10:39:00        93.152727
# 2010-12-01 10:47:00        36.277143
# ...

# %%
date_ave = pd.DataFrame(date_ave, columns = ['Date', 'ave_amount_spent'])

# %%
date_ave.Date[date_ave.Date.str.startswith('')]
