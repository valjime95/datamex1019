# %%
#!pip3 install folium
#!pip3 install googlemaps

# %%
import pandas as pd
import numpy as np 
from pymongo import MongoClient
import folium
import googlemaps
import requests
import json

# %%
# crear base de datos
client=MongoClient()
db=client.A
colec = db.a

# %%
# vamos a ver todas categorías que existen en la base
query = list(colec.find({'$and':[{'number_of_employees': {'$lte':50,'$gte':10}},\
                               {'founded_year':{'$gte': 2008}},\
                                {'offices':{'$ne':True}}]},\
                      {'_id':0, 'name':1,'category_code':1,'number_of_employees':1,\
                       'founded_year':1,'offices':1}))

# %%
query = pd.DataFrame(query)
print(query)
query=query.dropna()
query.index = range(len(query))
len(query)
# Out:
#        category_code  founded_year                       name  \
# 0           software          2008                    GoingOn
# 1        games_video          2008                Crunchyroll
# 2            finance          2011                   CircleUp
# 3             search          2012                    PeekYou
# 4             mobile          2010                      GENWI
# 5                web          2013                      Fixya
# 6             mobile          2009                   Mobovivo
# 7         enterprise          2010                    Needium
# 8              other          2012                  Widgetbox
# 9    network_hosting          2008                    Webnode
# 10       games_video          2008                WonderHowTo
# 11               web          2008                First30Days
# 12        enterprise          2008                     Mibura
# 13            mobile          2008                      Jirbo
# 14              news          2008                  fotopedia
# 15         analytics          2010                  YouNoodle
# 16               web          2008                   Particle
# 17               web          2008                     CityIN
# 18       advertising          2008                     Sprout
# 19          software          2012                 Simplicant
# 20        enterprise          2008                       Gnip
# 21        enterprise          2008                  CloudMade
# 22       games_video          2008                     Clipta
# 23          software          2008                 VisualSage
# 24               web          2008                  BuyerRaja
# 25               web          2008                     Weplay
# 26         cleantech          2008                       Akvo
# 27          software          2008                     Woopra
# 28       games_video          2008                 AudioMicro
# 29          software          2008                    Cotendo
# ..               ...           ...                        ...
# 556        ecommerce          2008  Steppy Frog Design Studio
# 557              web          2008                    DoNanza
# 558              web          2008                     DSwiss
# 559           mobile          2009                   Wikitude
# 560       enterprise          2008   Orbis Media Technologies
# 561           mobile          2008           Mobiles Republic
# 562         software          2008                   ubigrate
# 563         software          2009           LugIron Software
# 564      advertising          2008                DoTradeEasy
# 565           mobile          2009                   Appsfire
# 566      advertising          2008                      Struq
# 567              web          2009              ChallengePost
# 568       consulting          2008                    Kear IT
# 569            other          2008        Nanu Media Services
# 570              web          2009                    Teambox
# 571       consulting          2008               SalesInsight
# 572         software          2008                  Testplant
# 573        ecommerce          2009                    Clickom
# 574        analytics          2008                   Homesnap
# 575              web          2008                Culture Jam
# 576         software          2008                 Inq Mobile
# 577         software          2009              Tiverias Apps
# 578         software          2009         Luma International
# 579         software          2008          Continuity Engine
# 580        ecommerce          2008          Pipit Interactive
# 581              web          2008               Conversition
# 582      advertising          2008                   phinditt
# 583       enterprise          2008                      Jelli
# 584      games_video          2009                 Tiny Speck
# 585           mobile          2009                     Getyoo
#
#      number_of_employees                                            offices
# 0                     40  [{'description': 'GoingOn Networks, Inc.', 'ad...
# 1                     50  [{'description': '', 'address1': '', 'address2...
# 2                     11  [{'description': '', 'address1': '', 'address2...
# 3                     20  [{'description': None, 'address1': None, 'addr...
# 4                     25  [{'description': '', 'address1': '4966 El Cami...
# 5                     30  [{'description': '', 'address1': 'One Franklin...
# 6                     22  [{'description': 'Canadian', 'address1': '1400...
# 7                     15  [{'description': 'Needium HQ', 'address1': '46...
# 8                     30  [{'description': None, 'address1': None, 'addr...
# 9                     30  [{'description': '', 'address1': 'U vodarny 2'...
# 10                    12  [{'description': None, 'address1': '1832 Frank...
# 11                    17  [{'description': None, 'address1': '1760 Frank...
# 12                    10  [{'description': None, 'address1': '8335 Sunse...
# 13                    23  [{'description': 'World Headquarters', 'addres...
# 14                    17  [{'description': 'Paris', 'address1': '', 'add...
# 15                    18  [{'description': '', 'address1': '330 Townsend...
# 16                    12  [{'description': 'Particle', 'address1': '540 ...
# 17                    11  [{'description': None, 'address1': '', 'addres...
# 18                    18  [{'description': 'Hawaii Office', 'address1': ...
# 19                    10  [{'description': '', 'address1': '', 'address2...
# 20                    34  [{'description': '', 'address1': '1050 Walnut'...
# 21                    45  [{'description': 'London Office', 'address1': ...
# 22                    16  [{'description': 'Corporate Headquarters', 'ad...
# 23                    50                                                 []
# 24                    20  [{'description': None, 'address1': '#539,16th ...
# 25                    10  [{'description': 'New York Office', 'address1'...
# 26                    10  [{'description': None, 'address1': 'c/o NWP', ...
# 27                    12  [{'description': '', 'address1': '', 'address2...
# 28                    10  [{'description': '', 'address1': '13351-D Rive...
# 29                    30  [{'description': 'EMEA', 'address1': '4 Hagavi...
# ..                   ...                                                ...
# 556                   50  [{'description': 'Steppy Frog Design Studio', ...
# 557                   10  [{'description': 'Israel Office', 'address1': ...
# 558                   10  [{'description': 'DSwiss AG', 'address1': 'Bad...
# 559                   20  [{'description': 'Headquarter', 'address1': 'S...
# 560                   10  [{'description': 'Orbis Media Technologies', '...
# 561                   25  [{'description': '', 'address1': '2, Rue Rober...
# 562                   12  [{'description': '', 'address1': 'Herkulesstr....
# 563                   10  [{'description': 'World Headquarters', 'addres...
# 564                   10  [{'description': 'DoTradeEasy Ltd', 'address1'...
# 565                   14  [{'description': 'Headquarter', 'address1': ''...
# 566                   50  [{'description': 'London HQ', 'address1': '5th...
# 567                   17  [{'description': '', 'address1': '425 West 13t...
# 568                   15  [{'description': '', 'address1': '1510-H Caton...
# 569                   10  [{'description': 'AskNanu.com', 'address1': ''...
# 570                   35  [{'description': 'Barcelona Office', 'address1...
# 571                   11  [{'description': 'Headquarter', 'address1': 'E...
# 572                   50  [{'description': 'TestPlant', 'address1': '6 S...
# 573                   11  [{'description': 'Main Office', 'address1': '3...
# 574                   18  [{'description': 'HQ', 'address1': '5335 Wisco...
# 575                   15  [{'description': '', 'address1': '2434 Lincoln...
# 576                   40  [{'description': 'London', 'address1': '', 'ad...
# 577                   20  [{'description': 'Tiverias Apps LLC.', 'addres...
# 578                   40  [{'description': 'Headquarters', 'address1': '...
# 579                   11  [{'description': 'HQ', 'address1': '150 Munson...
# 580                   10  [{'description': 'Los Angeles', 'address1': '1...
# 581                   10  [{'description': 'HQ', 'address1': '', 'addres...
# 582                   10  [{'description': 'suite', 'address1': '', 'add...
# 583                   12  [{'description': 'Jelli, Inc.', 'address1': '4...
# 584                   45  [{'description': '', 'address1': '163 Hastings...
# 585                   10  [{'description': 'HQ', 'address1': 'Rue des Ta...
#
# [586 rows x 5 columns]
# 585

# %%
index_drop = [i for i in range(len(query)) if query['offices'][i] == []]
query = query.drop(index_drop) 
query.index = range(len(query))
len(index_drop)
# Out:
# 69

# %%
len(query)
# Out:
# 516

# %%
query.head()
# Out:
#   category_code  founded_year         name  number_of_employees  \
# 0      software          2008      GoingOn                   40
# 1   games_video          2008  Crunchyroll                   50
# 2       finance          2011     CircleUp                   11
# 3        search          2012      PeekYou                   20
# 4        mobile          2010        GENWI                   25
#
#                                              offices
# 0  [{'description': 'GoingOn Networks, Inc.', 'ad...
# 1  [{'description': '', 'address1': '', 'address2...
# 2  [{'description': '', 'address1': '', 'address2...
# 3  [{'description': None, 'address1': None, 'addr...
# 4  [{'description': '', 'address1': '4966 El Cami...

# %%
query.offices[100][0]
# Out:
# {'address1': 'Via Andrea Cesalpino, 60',
#  'address2': '',
#  'city': 'Milan',
#  'country_code': 'ITA',
#  'description': 'Milan Office',
#  'latitude': 45.507014,
#  'longitude': 9.2298577,
#  'state_code': None,
#  'zip_code': '20128'}

# %%
def get_first(data):
    res=[]
    ofi=[]
    
    data=data['offices']
    for e in data:
        principal=None   # solo las tienen geodata
        if e[0]['latitude'] and e[0]['longitude']:
            principal={'type':'Point',
                       'city': e[0]['city'],
                       'country code': e[0]['country_code'],
                       'coordinates':[
                           e[0]['longitude'],
                           e[0]['latitude']
                           
                       ]}
            
        ofi.append(principal)
        
        res.append({
            'total_offices':len(e),
            'lat':e[0]['latitude'],
            'lng':e[0]['longitude'],
            'oficina_principal':principal
        })
    
    return res, ofi

# %%
from pandas.io.json import json_normalize

first_office=json_normalize(get_first(query)[0])
first_office['oficina_principal']=get_first(query)[1]
first_office.head()
# Out:
#          lat         lng                                  oficina_principal  \
# 0  37.782263 -122.392142  {'type': 'Point', 'city': 'San Francisco', 'co...
# 1  37.781265 -122.393229  {'type': 'Point', 'city': 'San Francisco', 'co...
# 2        NaN         NaN                                               None
# 3  40.757929  -73.985506  {'type': 'Point', 'city': 'New York', 'country...
# 4  33.817100 -111.903500  {'type': 'Point', 'city': 'Los Altos', 'countr...
#
#   oficina_principal.city oficina_principal.coordinates  \
# 0          San Francisco      [-122.392142, 37.782263]
# 1          San Francisco      [-122.393229, 37.781265]
# 2                    NaN                           NaN
# 3               New York       [-73.985506, 40.757929]
# 4              Los Altos          [-111.9035, 33.8171]
#
#   oficina_principal.country code oficina_principal.type  total_offices
# 0                            USA                  Point              1
# 1                            USA                  Point              1
# 2                            NaN                    NaN              1
# 3                            USA                  Point              1
# 4                            USA                  Point              1

# %%
df_clean=pd.concat([query, first_office], axis=1)
df_clean = df_clean.drop(['offices','oficina_principal','oficina_principal.coordinates','oficina_principal.type'],axis = 1)
df_clean.head()
# Out:
#   category_code  founded_year         name  number_of_employees        lat  \
# 0      software          2008      GoingOn                   40  37.782263
# 1   games_video          2008  Crunchyroll                   50  37.781265
# 2       finance          2011     CircleUp                   11        NaN
# 3        search          2012      PeekYou                   20  40.757929
# 4        mobile          2010        GENWI                   25  33.817100
#
#           lng oficina_principal.city oficina_principal.country code  \
# 0 -122.392142          San Francisco                            USA
# 1 -122.393229          San Francisco                            USA
# 2         NaN                    NaN                            NaN
# 3  -73.985506               New York                            USA
# 4 -111.903500              Los Altos                            USA
#
#    total_offices
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
df_clean.isnull().sum()
# Out:
# category_code                       0
# founded_year                        0
# name                                0
# number_of_employees                 0
# lat                               132
# lng                               132
# oficina_principal.city            132
# oficina_principal.country code    132
# total_offices                       0
# dtype: int64

# %%
len(df_clean)
# Out:
# 516

# %%
data = df_clean.dropna()
data.index = range(len(data))

# %%
len(data)
# Out:
# 384

# %%
data.columns
# Out:
# Index(['category_code', 'founded_year', 'name', 'number_of_employees', 'lat',
#        'lng', 'oficina_principal.city', 'oficina_principal.country code',
#        'total_offices'],
#       dtype='object')

# %%
#filtro por categorías que me interesan
data_cat = data[(data.category_code == 'analytics') |(data.category_code == 'network_hosting')|(data.category_code == 'web')]

len(data_cat)
data_cat.index = range(len(data_cat))
data_cat.head()
# Out:
#      category_code  founded_year         name  number_of_employees        lat  \
# 0              web          2013        Fixya                   30  37.566879
# 1  network_hosting          2008      Webnode                   30  49.225902
# 2              web          2008  First30Days                   17  38.257035
# 3        analytics          2010    YouNoodle                   18  37.776659
# 4              web          2008       CityIN                   11  35.861660
#
#           lng oficina_principal.city oficina_principal.country code  \
# 0 -122.323895              San Mateo                            USA
# 1   16.569282                   Brno                            CZE
# 2  -85.717393             Louisville                            USA
# 3 -122.395875          San Francisco                            USA
# 4  104.195397                                                   CHN
#
#    total_offices
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
len(data_cat)
# Out:
# 89

# %%
# MAPA
mapa=folium.Map(location=[19.41, -99.16], tiles='cartodbpositron', zoom_start=1)
lat = list(data_cat['lat'])
long = list(data_cat['lng'])

for i in range(len(lat)):
    folium.Marker([lat[i],long[i]], icon=folium.Icon(color = "red")).add_to(mapa)

# %%
# mapa tiene 89 posibles ubicaciones, vamos a filtrar por mas cosas
# Filtramos por que tengan una sola oficina
data_cat = data_cat[(data_cat.total_offices == 1)]
len(data_cat)
# Out:
# 75

# %%
data_cat.head()
# Out:
#      category_code  founded_year         name  number_of_employees        lat  \
# 0              web          2013        Fixya                   30  37.566879
# 1  network_hosting          2008      Webnode                   30  49.225902
# 2              web          2008  First30Days                   17  38.257035
# 3        analytics          2010    YouNoodle                   18  37.776659
# 4              web          2008       CityIN                   11  35.861660
#
#           lng oficina_principal.city oficina_principal.country code  \
# 0 -122.323895              San Mateo                            USA
# 1   16.569282                   Brno                            CZE
# 2  -85.717393             Louisville                            USA
# 3 -122.395875          San Francisco                            USA
# 4  104.195397                                                   CHN
#
#    total_offices
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
set(data_cat['oficina_principal.country code'])
# Out:
# {'AUS',
#  'BEL',
#  'CAN',
#  'CHE',
#  'CHN',
#  'CZE',
#  'DEU',
#  'FRA',
#  'GBR',
#  'IND',
#  'IRL',
#  'NLD',
#  'NOR',
#  'NZL',
#  'PER',
#  'SGP',
#  'USA'}

# %%
data_cat.to_csv('datos_limpios.csv')

# %% [markdown]
# Vamos dividir las coordenadas dependiendo de si son noroeste, noreste, sureste, suroeste.
#
# Latitud
#
# N  (+)   S (-)
#
#
# Longitud
#
#
# E  (+)   0 (-)

# %%
nor_este = data_cat[(data_cat.lat > 0) & (data_cat.lng > 0)]
nor_oeste = data_cat[(data_cat.lat > 0) & (data_cat.lng < 0)]

sur_este = data_cat[(data_cat.lat < 0) & (data_cat.lng > 0)]
sur_oeste = data_cat[(data_cat.lat < 0) & (data_cat.lng < 0)]

# %%
print(len(nor_este))
print(len(nor_oeste))
print(len(sur_este))
print(len(sur_oeste))
# Out:
# 17
# 53
# 4
# 1

# %%
mapita =folium.Map(location=[0,0], tiles='cartodbpositron', zoom_start=2)

def mapa(db, colores):
    lat = list(db['lat'])
    long = list(db['lng'])
    
    for i in range(len(lat)):
        folium.Marker([lat[i],long[i]], icon=folium.Icon(color = str(colores))).add_to(mapita)
    
    return mapita
mapa(nor_este, colores = 'blue')
mapa(nor_oeste, colores = 'darkblue')
mapa(sur_este, colores = 'green')
mapa(sur_oeste, colores = 'darkgreen')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapita.save('mapita1.html')

# %%
lat = list(data_cat['lat'])
long = list(data_cat['lng'])

# %%
#  I. Condición: Aeropuertos cerca
req = requests.get('https://gist.githubusercontent.com/tdreyno/4278655/raw/7b0762c09b519f40397e4c3e100b097d861f5588/airports.json')
req
# Out:
# <Response [200]>

# %%
results=req.json()
airports=pd.DataFrame(results)

# %%
air = airports.drop(['carriers','direct_flights','elev','email','phone','runway_length','tz','url','woeid'], axis=1)
air = air[air.type == 'Airports']
air.columns = ['city', 'code', 'country', 'icao', 'lat', 'lng', 'name', 'state','type']

# %%
air['lat']=air['lat'].astype(float)
air['lng']=air['lng'].astype(float)

# %%
Anor_este = air[(air.lat > 0) & (air.lng > 0)]
Anor_oeste = air[(air.lat > 0) & (air.lng < 0)]

Asur_este = air[(air.lat < 0) & (air.lng > 0)]
Asur_oeste = air[(air.lat < 0) & (air.lng < 0)]

# %%
print(len(Anor_este))
print(len(Anor_oeste))
print(len(Asur_este))
print(len(Asur_oeste))


17
53
4
1
# Out:
# 1391
# 1413
# 450
# 246

# %%
Anor_este
# Out:
#                    city code               country  icao        lat  \
# 1               El Tarf  AAE               Algeria  DABB  36.823600
# 3783   22.88870                Satu Mare Airport                Satu Mare
# 3787   30.79780                                                     Nebbi
# 3799  113.36700             Zhongshan Ferry Port                Guangdong
# 3803  110.36200                Zhanjiang Airport                Guangdong
# 3809  110.48300
# 3831    7.31024                  Rheinland-Pfalz          Rheinland-Pfalz
# 3834    8.56137     Zurich International Airport         Canton of Zurich
# 3851   20.88470                Zakinthos Airport             Nisia Ionioy
# 3852  113.67200                       Humen Port                Guangdong
# 3861  113.55700                   Zhuhai Airport                Guangdong
# 3865  104.76300              Savannakhet Airport             Savannahkhet
# 3877  114.35000                      Shekou Port                      湖北省
# 3878   91.87440            Osmany Sylhet Airport                   Sylhet
#
#           type
# 1     Airports
# 2     Airports
# 4     Airports
# 5     Airports
# 6     Airports
# 7     Airports
# 9     Airports
# 10    Airports
# 12    Airports
# 16    Airports
# 21    Airports
# 22    Airports
# 23    Airports
# 30    Airports
# 34    Airports
# 37    Airports
# 39    Airports
# 40    Airports
# 41    Airports
# 42    Airports
# 43    Airports
# 44    Airports
# 45    Airports
# 49    Airports
# 52    Airports
# 54    Airports
# 55    Airports
# 61    Airports
# 63    Airports
# 65    Airports
# ...        ...
# 3598  Airports
# 3602  Airports
# 3610  Airports
# 3627  Airports
# 3632  Airports
# 3636  Airports
# 3637  Airports
# 3638  Airports
# 3690  Airports
# 3762  Airports
# 3763  Airports
# 3764  Airports
# 3766  Airports
# 3768  Airports
# 3774  Airports
# 3775  Airports
# 3782  Airports
# 3783  Airports
# 3787  Airports
# 3799  Airports
# 3803  Airports
# 3809  Airports
# 3831  Airports
# 3834  Airports
# 3851  Airports
# 3852  Airports
# 3861  Airports
# 3865  Airports
# 3877  Airports
# 3878  Airports
#
# [1391 rows x 9 columns]

# %%
for i in nor_este:

# %%
import math
def calculate_distance(self, lat1, lon1, lat2, lon2):
        '''
        * Calculates the distance between two points given their (lat, lon) co-ordinates.
        * It uses the Spherical Law Of Cosines (http://en.wikipedia.org/wiki/Spherical_law_of_cosines):
        *
        * cos(c) = cos(a) * cos(b) + sin(a) * sin(b) * cos(C)                        (1)
        *
        * In this case:
        * a = lat1 in radians, b = lat2 in radians, C = (lon2 - lon1) in radians
        * and because the latitude range is  [-π/2, π/2] instead of [0, π]
        * and the longitude range is [-π, π] instead of [0, 2π]
        * (1) transforms into:
        *
        * x = cos(c) = sin(a) * sin(b) + cos(a) * cos(b) * cos(C)
        *
        * Finally the distance is arccos(x)
        '''

        if ((lat1 == lat2) and (lon1 == lon2)):
            return 0

        try:
            delta = lon2 - lon1
            a = math.radians(lat1)
            b = math.radians(lat2)
            C = math.radians(delta)
            x = math.sin(a) * math.sin(b) + math.cos(a) * math.cos(b) * math.cos(C)
            distance = math.acos(x) # in radians
            distance  = math.degrees(distance) # in degrees
            distance  = distance * 60 # 60 nautical miles / lat degree
            distance = distance * 1852 # conversion to meters
            distance  = round(distance)
            return distance;
        except:
            return 0
