# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
import feedparser

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
burner = feedparser.parse('http://feeds.feedburner.com/oreilly/radar/atom')
burner
# Out:
# {'bozo': 0,
#  'encoding': 'UTF-8',
#  'entries': [{'author': 'Mac Slocum',
#    'author_detail': {'name': 'Mac Slocum'},
#    'authors': [{'name': 'Mac Slocum'}],
#    'comments': 'https://www.oreilly.com/radar/highlights-from-software-architecture-berlin-2019/#respond',
#    'content': [{'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'language': None,
#      'type': 'text/html',
#      'value': '<p>Experts from across the software architecture world came together in Berlin for the <a href="https://conferences.oreilly.com/software-architecture/sa-eu">O&#8217;Reilly Software Architecture Conference</a>. Below you&#8217;ll find links to highlights from the event.</p>\n<h2>Cognitive biases in the architect&#8217;s life</h2>\n<p>Birgitta Boeckeler covers some of the cognitive biases that can trip up architects.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/cognitive-biases-in-the-architects-life">Cognitive biases in the architect&#8217;s life</a>&#8220;</li>\n</ul>\n<h2>The three-headed dog: Architecture, process, structure</h2>\n<p>Allen Holub shows you how architecture, process, and structure interact, and how to fix misalignment that’s sucking the life out of your productivity.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/the-three-headed-dog-architecture-process-structure">The three-headed dog: Architecture, process, structure</a>&#8220;</li>\n</ul>\n<h2>Modern machine learning architectures: Data and hardware and platform, oh my</h2>\n<p>Brian Sletten takes a deep dive into the intersection of data, models, hardware, language, architecture, and machine learning systems.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/modern-machine-learning-architectures">Modern machine learning architectures: Data and hardware and platform, oh my</a>&#8220;</li>\n</ul>\n<h2>From the trenches: Patrick Kua</h2>\n<p>Neal Ford interviews Patrick Kua about his career path and his work as an architect.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/from-the-trenches-patrick-kua">From the trenches: Patrick Kua</a>&#8220;</li>\n</ul>\n<h2>The new norms of cloud native</h2>\n<p>Cheryl Hung discusses the state of cloud native tools and communities.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/the-new-norms-of-cloud-native">The new norms of cloud native</a>&#8220;</li>\n</ul>\n<div class="hidden">\n<!--unsigned--></p>\n<h2>Next data platform architecture: Distributed Data Mesh</h2>\n<p>Zhamak Dehghani introduces data mesh, the next-generation data platform that draws from modern distributed architecture.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/next-data-platform-architecture-distributed-data-mesh">Next data platform architecture: Distributed Data Mesh</a>&#8220;</li>\n</ul>\n</div>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/XFnuaWaXgQI" height="1" width="1" alt=""/>'}],
#    'feedburner_origlink': 'https://www.oreilly.com/radar/highlights-from-software-architecture-berlin-2019/',
#    'guidislink': False,
#    'id': 'https://www.oreilly.com/radar/?p=10569',
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/XFnuaWaXgQI/',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/XFnuaWaXgQI/',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'published': 'Thu, 07 Nov 2019 20:10:44 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=20, tm_min=10, tm_sec=44, tm_wday=3, tm_yday=311, tm_isdst=0),
#    'slash_comments': '0',
#    'summary': 'Experts from across the software architecture world came together in Berlin for the O&#8217;Reilly Software Architecture Conference. Below you&#8217;ll find links to highlights from the event. Cognitive biases in the architect&#8217;s life Birgitta Boeckeler covers some of the cognitive biases that can trip up architects. Watch &#8220;Cognitive biases in the architect&#8217;s life&#8220; The three-headed dog: [&#8230;]',
#    'summary_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/html',
#     'value': 'Experts from across the software architecture world came together in Berlin for the O&#8217;Reilly Software Architecture Conference. Below you&#8217;ll find links to highlights from the event. Cognitive biases in the architect&#8217;s life Birgitta Boeckeler covers some of the cognitive biases that can trip up architects. Watch &#8220;Cognitive biases in the architect&#8217;s life&#8220; The three-headed dog: [&#8230;]'},
#    'tags': [{'label': None, 'scheme': None, 'term': 'Next Architecture'},
#     {'label': None, 'scheme': None, 'term': 'Signals'},
#     {'label': None,
#      'scheme': None,
#      'term': 'Software Architecture Berlin 2019'}],
#    'title': 'Highlights from the O’Reilly Software Architecture Conference in Berlin 2019',
#    'title_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/plain',
#     'value': 'Highlights from the O’Reilly Software Architecture Conference in Berlin 2019'},
#    'wfw_commentrss': 'https://www.oreilly.com/radar/highlights-from-software-architecture-berlin-2019/feed/'},
#   {'author': 'Mac Slocum',
#    'author_detail': {'name': 'Mac Slocum'},
#    'authors': [{'name': 'Mac Slocum'}],
#    'comments': 'https://www.oreilly.com/radar/highlights-from-velocity-berlin-2019/#respond',
#    'content': [{'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'language': None,
#      'type': 'text/html',
#      'value': '<p>People from across the cloud native and distributed systems worlds came together in Berlin for the <a href="https://conferences.oreilly.com/velocity/vl-eu">O&#8217;Reilly Velocity Conference</a>. Below you&#8217;ll find links to highlights from the event.</p>\n<h2>My love letter to computer science is very short and I also forgot to mail it</h2>\n<p>James Mickens shares his concerns and frustrations with today&#8217;s technology.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/my-love-letter-to-computer-science-is-very-short">My love letter to computer science is very short and I also forgot to mail ity</a>&#8220;</li>\n</ul>\n<h2>Everything is a little bit broken; or, The illusion of control</h2>\n<p>Heidi Waterhouse outlines ways to handle uncertainty by adding in error budgets, layered access, and other accommodations for failure.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/everything-is-a-little-bit-broken">Everything is a little bit broken; or, The illusion of control</a>&#8220;</li>\n</ul>\n<h2>Observability: Understanding production through your customers&#8217; eyes</h2>\n<p>Christine Yen says observability isn’t just for ops folks, but it’s not only about engineering roles, either.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/observability-understanding-production-through-your-customers-eyes">Observability: Understanding production through your customers&#8217; eyes</a>&#8220;</li>\n</ul>\n<h2>Secure reliable systems</h2>\n<p>Ana Oprea provides insights and strategies for baking security into your systems.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/secure-reliable-systems-velocity-eu-19">Secure reliable systems</a>&#8220;</li>\n</ul>\n<h2>How to deploy infrastructure in just 13.8 billion years</h2>\n<p>Ingrid Burrington looks at how reframing the time scales of computation can change the way your build infrastructure.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/how-to-deploy-infrastructure-in-just-13-point-8-billion-years">How to deploy infrastructure in just 13.8 billion years</a>&#8220;</li>\n</ul>\n<h2>The ultimate guide to complicated systems</h2>\n<p>Jennifer Davis explores how sustainable engineering practices can enable technical and strategic direction.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/the-ultimate-guide-to-complicated-systems">The ultimate guide to complicated systems</a>&#8220;</li>\n</ul>\n<h2>5 things Go taught me about open source?</h2>\n<p>Dave Cheney talks about the unexpected things he learned while trying to convince programmers to try Go.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/5-things-go-taught-me-about-open-source">5 things Go taught me about open source?</a>&#8220;</li>\n</ul>\n<h2>Building high-performing engineering teams, one pixel at a time</h2>\n<p>Lena Reinhard discusses ways you can make distributed teams strong, deliberate, and productive.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/building-high-performing-engineering-teams-one-pixel-at-a-time">Building high-performing engineering teams, one pixel at a time</a>&#8220;</li>\n</ul>\n<h2>Controlled chaos: The inevitable marriage of DevOps and security</h2>\n<p>Kelly Shortridge explains why chaos and resilience engineering represent the future of security programs.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/controlled-chaos-the-inevitable-marriage-of-devops-and-security">Controlled chaos: The inevitable marriage of DevOps and security</a>&#8220;</li>\n</ul>\n<div class="hidden">\n<!--unsigned--></p>\n<h2>The power of good abstractions in systems design</h2>\n<p>Lorenzo Saino looks at how good abstractions make it possible to identify and apply solutions to seemingly unrelated problems.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/the-power-of-good-abstractions-in-systems-design">The powe ...
#    'feedburner_origlink': 'https://www.oreilly.com/radar/highlights-from-velocity-berlin-2019/',
#    'guidislink': False,
#    'id': 'https://www.oreilly.com/radar/?p=10577',
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/V2KqZ95Mbgs/',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/V2KqZ95Mbgs/',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'published': 'Thu, 07 Nov 2019 20:09:07 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=20, tm_min=9, tm_sec=7, tm_wday=3, tm_yday=311, tm_isdst=0),
#    'slash_comments': '0',
#    'summary': 'People from across the cloud native and distributed systems worlds came together in Berlin for the O&#8217;Reilly Velocity Conference. Below you&#8217;ll find links to highlights from the event. My love letter to computer science is very short and I also forgot to mail it James Mickens shares his concerns and frustrations with today&#8217;s technology. Watch [&#8230;]',
#    'summary_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/html',
#     'value': 'People from across the cloud native and distributed systems worlds came together in Berlin for the O&#8217;Reilly Velocity Conference. Below you&#8217;ll find links to highlights from the event. My love letter to computer science is very short and I also forgot to mail it James Mickens shares his concerns and frustrations with today&#8217;s technology. Watch [&#8230;]'},
#    'tags': [{'label': None, 'scheme': None, 'term': 'Next Architecture'},
#     {'label': None, 'scheme': None, 'term': 'Signals'},
#     {'label': None,
#      'scheme': None,
#      'term': 'Velocity Conference Berlin 2019'}],
#    'title': 'Highlights from the O’Reilly Velocity Conference in Berlin 2019',
#    'title_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/plain',
#     'value': 'Highlights from the O’Reilly Velocity Conference in Berlin 2019'},
#    'wfw_commentrss': 'https://www.oreilly.com/radar/highlights-from-velocity-berlin-2019/feed/'},
#   {'author': 'Patrick Kua and Neal Ford',
#    'author_detail': {'name': 'Patrick Kua and Neal Ford'},
#    'authors': [{'name': 'Patrick Kua and Neal Ford'}],
#    'comments': 'https://www.oreilly.com/radar/from-the-trenches-patrick-kua/#respond',
#    'content': [{'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'language': None,
#      'type': 'text/html',
#      'value': '<p>This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. <a href="https://learning.oreilly.com/videos/oreilly-software-architecture/9781492050728/9781492050728-video328593">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-software-architecture-berlin-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/0JSKwm4FfEE" height="1" width="1" alt=""/>'}],
#    'feedburner_origlink': 'https://www.oreilly.com/radar/from-the-trenches-patrick-kua/',
#    'guidislink': False,
#    'id': 'https://www.oreilly.com/radar/?p=10503',
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/0JSKwm4FfEE/',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/0JSKwm4FfEE/',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'published': 'Thu, 07 Nov 2019 20:00:48 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=20, tm_min=0, tm_sec=48, tm_wday=3, tm_yday=311, tm_isdst=0),
#    'slash_comments': '0',
#    'summary': 'This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#    'summary_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/html',
#     'value': 'This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#    'tags': [{'label': None, 'scheme': None, 'term': 'Next Architecture'},
#     {'label': None,
#      'scheme': None,
#      'term': 'Software Architecture Berlin 2019'}],
#    'title': 'From the trenches: Patrick Kua',
#    'title_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/plain',
#     'value': 'From the trenches: Patrick Kua'},
#    'wfw_commentrss': 'https://www.oreilly.com/radar/from-the-trenches-patrick-kua/feed/'},
#   {'author': 'Dave Cheney',
#    'author_detail': {'name': 'Dave Cheney'},
#    'authors': [{'name': 'Dave Cheney'}],
#    'comments': 'https://www.oreilly.com/radar/5-things-go-taught-me-about-open-source/#respond',
#    'content': [{'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'language': None,
#      'type': 'text/html',
#      'value': '<p>This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. <a href="https://learning.oreilly.com/videos/oreilly-velocity-conference/9781492050742/9781492050742-video328471">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-velocity-berlin-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/9I22_Ca0KFU" height="1" width="1" alt=""/>'}],
#    'feedburner_origlink': 'https://www.oreilly.com/radar/5-things-go-taught-me-about-open-source/',
#    'guidislink': False,
#    'id': 'https://www.oreilly.com/radar/?p=10549',
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9I22_Ca0KFU/',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9I22_Ca0KFU/',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'published': 'Thu, 07 Nov 2019 20:00:38 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=20, tm_min=0, tm_sec=38, tm_wday=3, tm_yday=311, tm_isdst=0),
#    'slash_comments': '0',
#    'summary': 'This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#    'summary_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/html',
#     'value': 'This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#    'tags': [{'label': None, 'scheme': None, 'term': 'Next Architecture'},
#     {'label': None,
#      'scheme': None,
#      'term': 'Velocity Conference Berlin 2019'}],
#    'title': '5 things Go taught me about open source?',
#    'title_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/plain',
#     'value': '5 things Go taught me about open source?'},
#    'wfw_commentrss': 'https://www.oreilly.com/radar/5-things-go-taught-me-about-open-source/feed/'},
#   {'author': 'Lena Reinhard',
#    'author_detail': {'name': 'Lena Reinhard'},
#    'authors': [{'name': 'Lena Reinhard'}],
#    'comments': 'https://www.oreilly.com/radar/building-high-performing-engineering-teams-one-pixel-at-a-time/#respond',
#    'content': [{'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'language': None,
#      'type': 'text/html',
#      'value': '<p>This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. <a href="https://learning.oreilly.com/videos/oreilly-velocity-conference/9781492050742/9781492050742-video328473">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-velocity-berlin-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/yB2DA73brho" height="1" width="1" alt=""/>'}],
#    'feedburner_origlink': 'https://www.oreilly.com/radar/building-high-performing-engineering-teams-one-pixel-at-a-time/',
#    'guidislink': False,
#    'id': 'https://www.oreilly.com/radar/?p=10556',
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/yB2DA73brho/',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/yB2DA73brho/',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'published': 'Thu, 07 Nov 2019 20:00:35 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=20, tm_min=0, tm_sec=35, tm_wday=3, tm_yday=311, tm_isdst=0),
#    'slash_comments': '0',
#    'summary': 'This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#    'summary_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/html',
#     'value': 'This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#    'tags': [{'label': None, 'scheme': None, 'term': 'Next Architecture'},
#     {'label': None,
#      'scheme': None,
#      'term': 'Velocity Conference Berlin 2019'}],
#    'title': 'Building high-performing engineering teams, one pixel at a time',
#    'title_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/plain',
#     'value': 'Building high-performing engineering teams, one pixel at a time'},
#    'wfw_commentrss': 'https://www.oreilly.com/radar/building-high-performing-engineering-teams-one-pixel-at-a-time/feed/'},
#   {'author': 'Ingrid Burrington',
#    'author_detail': {'name': 'Ingrid Burrington'},
#    'authors': [{'name': 'Ingrid Burrington'}],
#    'comments': 'https://www.oreilly.com/radar/how-to-deploy-infrastructure-in-just-13-point-8-billion-years/#respond',
#    'content': [{'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'language': None,
#      'type': 'text/html',
#      'value': '<p>This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. <a href="https://learning.oreilly.com/videos/oreilly-velocity-conference/9781492050742/9781492050742-video328470">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-velocity-berlin-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/Y5gT1Cvqv1U" height="1" width="1" alt=""/>'}],
#    'feedburner_origlink': 'https://www.oreilly.com/radar/how-to-deploy-infrastructure-in-just-13-point-8-billion-years/',
#    'guidislink': False,
#    'id': 'https://www.oreilly.com/radar/?p=10536',
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/Y5gT1Cvqv1U/',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/Y5gT1Cvqv1U/',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'published': 'Thu, 07 Nov 2019 20:00:34 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=20, tm_min=0, tm_sec=34, tm_wday=3, tm_yday=311, tm_isdst=0),
#    'slash_comments': '0',
#    'summary': 'This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#    'summary_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/html',
#     'value': 'This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#    'tags': [{'label': None, 'scheme': None, 'term': 'Next Architecture'},
#     {'label': None,
#      'scheme': None,
#      'term': 'Velocity Conference Berlin 2019'}],
#    'title': 'How to deploy infrastructure in just 13.8 billion years',
#    'title_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/plain',
#     'value': 'How to deploy infrastructure in just 13.8 billion years'},
#    'wfw_commentrss': 'https://www.oreilly.com/radar/how-to-deploy-infrastructure-in-just-13-point-8-billion-years/feed/'},
#   {'author': 'Kelly Shortridge',
#    'author_detail': {'name': 'Kelly Shortridge'},
#    'authors': [{'name': 'Kelly Shortridge'}],
#    'comments': 'https://www.oreilly.com/radar/controlled-chaos-the-inevitable-marriage-of-devops-and-security/#respond',
#    'content': [{'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'language': None,
#      'type': 'text/html',
#      'value': '<p>This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. <a href="https://learning.oreilly.com/videos/oreilly-velocity-conference/9781492050742/9781492050742-video328467">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-velocity-berlin-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/QnGi3gdzKj0" height="1" width="1" alt=""/>'}],
#    'feedburner_origlink': 'https://www.oreilly.com/radar/controlled-chaos-the-inevitable-marriage-of-devops-and-security/',
#    'guidislink': False,
#    'id': 'https://www.oreilly.com/radar/?p=10561',
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/QnGi3gdzKj0/',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/QnGi3gdzKj0/',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'published': 'Thu, 07 Nov 2019 20:00:30 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=20, tm_min=0, tm_sec=30, tm_wday=3, tm_yday=311, tm_isdst=0),
#    'slash_comments': '0',
#    'summary': 'This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#    'summary_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/html',
#     'value': 'This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#    'tags': [{'label': None, 'scheme': None, 'term': 'Next Architecture'},
#     {'label': None,
#      'scheme': None,
#      'term': 'Velocity Conference Berlin 2019'}],
#    'title': 'Controlled chaos: The inevitable marriage of DevOps and security',
#    'title_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/plain',
#     'value': 'Controlled chaos: The inevitable marriage of DevOps and security'},
#    'wfw_commentrss': 'https://www.oreilly.com/radar/controlled-chaos-the-inevitable-marriage-of-devops-and-security/feed/'},
#   {'author': 'Jennifer Davis',
#    'author_detail': {'name': 'Jennifer Davis'},
#    'authors': [{'name': 'Jennifer Davis'}],
#    'comments': 'https://www.oreilly.com/radar/the-ultimate-guide-to-complicated-systems/#respond',
#    'content': [{'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'language': None,
#      'type': 'text/html',
#      'value': '<p>This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. <a href="https://learning.oreilly.com/videos/oreilly-velocity-conference/9781492050742/9781492050742-video328466">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-velocity-berlin-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/AlXZ2UUW79M" height="1" width="1" alt=""/>'}],
#    'feedburner_origlink': 'https://www.oreilly.com/radar/the-ultimate-guide-to-complicated-systems/',
#    'guidislink': False,
#    'id': 'https://www.oreilly.com/radar/?p=10540',
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/AlXZ2UUW79M/',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/AlXZ2UUW79M/',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'published': 'Thu, 07 Nov 2019 20:00:17 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=20, tm_min=0, tm_sec=17, tm_wday=3, tm_yday=311, tm_isdst=0),
#    'slash_comments': '0',
#    'summary': 'This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#    'summary_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/html',
#     'value': 'This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#    'tags': [{'label': None, 'scheme': None, 'term': 'Next Architecture'},
#     {'label': None,
#      'scheme': None,
#      'term': 'Velocity Conference Berlin 2019'}],
#    'title': 'The ultimate guide to complicated systems',
#    'title_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/plain',
#     'value': 'The ultimate guide to complicated systems'},
#    'wfw_commentrss': 'https://www.oreilly.com/radar/the-ultimate-guide-to-complicated-systems/feed/'},
#   {'author': 'Birgitta Boeckeler',
#    'author_detail': {'name': 'Birgitta Boeckeler'},
#    'authors': [{'name': 'Birgitta Boeckeler'}],
#    'comments': 'https://www.oreilly.com/radar/cognitive-biases-in-the-architects-life/#respond',
#    'content': [{'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'language': None,
#      'type': 'text/html',
#      'value': '<p>This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. <a href="https://learning.oreilly.com/videos/oreilly-software-architecture/9781492050728/9781492050728-video328591">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-software-architecture-berlin-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/MCKQixUPlMQ" height="1" width="1" alt=""/>'}],
#    'feedburner_origlink': 'https://www.oreilly.com/radar/cognitive-biases-in-the-architects-life/',
#    'guidislink': False,
#    'id': 'https://www.oreilly.com/radar/?p=10497',
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/MCKQixUPlMQ/',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/MCKQixUPlMQ/',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'published': 'Thu, 07 Nov 2019 20:00:07 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=20, tm_min=0, tm_sec=7, tm_wday=3, tm_yday=311, tm_isdst=0),
#    'slash_comments': '0',
#    'summary': 'This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#    'summary_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/html',
#     'value': 'This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#    'tags': [{'label': None, 'scheme': None, 'term': 'Next Architecture'},
#     {'label': None,
#      'scheme': None,
#      'term': 'Software Architecture Berlin 2019'}],
#    'title': 'Cognitive biases in the architect’s life',
#    'title_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/plain',
#     'value': 'Cognitive biases in the architect’s life'},
#    'wfw_commentrss': 'https://www.oreilly.com/radar/cognitive-biases-in-the-architects-life/feed/'},
#   {'author': 'Allen Holub',
#    'author_detail': {'name': 'Allen Holub'},
#    'authors': [{'name': 'Allen Holub'}],
#    'comments': 'https://www.oreilly.com/radar/the-three-headed-dog-architecture-process-structure/#respond',
#    'content': [{'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'language': None,
#      'type': 'text/html',
#      'value': '<p>This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. <a href="https://learning.oreilly.com/videos/oreilly-software-architecture/9781492050728/9781492050728-video328592">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-software-architecture-berlin-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/tUBOtwDRLBU" height="1" width="1" alt=""/>'}],
#    'feedburner_origlink': 'https://www.oreilly.com/radar/the-three-headed-dog-architecture-process-structure/',
#    'guidislink': False,
#    'id': 'https://www.oreilly.com/radar/?p=10490',
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/tUBOtwDRLBU/',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/tUBOtwDRLBU/',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'published': 'Thu, 07 Nov 2019 20:00:06 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=20, tm_min=0, tm_sec=6, tm_wday=3, tm_yday=311, tm_isdst=0),
#    'slash_comments': '0',
#    'summary': 'This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#    'summary_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/html',
#     'value': 'This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#    'tags': [{'label': None, 'scheme': None, 'term': 'Next Architecture'},
#     {'label': None,
#      'scheme': None,
#      'term': 'Software Architecture Berlin 2019'}],
#    'title': 'The three-headed dog: Architecture, process, structure',
#    'title_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/plain',
#     'value': 'The three-headed dog: Architecture, process, structure'},
#    'wfw_commentrss': 'https://www.oreilly.com/radar/the-three-headed-dog-architecture-process-structure/feed/'},
#   {'author': 'Ben Lorica and Mike Loukides',
#    'author_detail': {'name': 'Ben Lorica and Mike Loukides'},
#    'authors': [{'name': 'Ben Lorica and Mike Loukides'}],
#    'comments': 'https://www.oreilly.com/radar/a-world-of-deepfakes/#respond',
#    'content': [{'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'language': None,
#      'type': 'text/html',
#      'value': '<p>Deepfakes have been very much in the news for the past two years. It’s time to think about what deepfakes are and what they mean. Where do they come from? Why now? Is this just a natural evolution in the history of technology?</p>\n\n\n\n<p>Deepfakes are media that are created by AI. They appear to be genuine (e.g., a <a href="https://www.theverge.com/tldr/2018/4/17/17247334/ai-fake-news-video-barack-obama-jordan-peele-buzzfeed">video of President Obama</a>) but have limited connection to reality. An audio track can be created that sounds indistinguishable from the victim, saying something the victim would never have said. Video can be generated from existing videos or photos that match the soundtrack, so that the mouth moves correctly and the facial expressions look natural. It’s not surprising that humans have trouble detecting fakes; with the current technology, even shallow fakes are too good.</p>\n\n\n\n<p>Deepfakes are the logical extension of older AI research. It wasn’t long ago that we read about AI generating new paintings in the style of <a href="https://www.pcworld.com/article/3053520/ai-just-3d-printed-a-brand-new-rembrandt-and-its-shockingly-good.html">Rembrandt</a> and other Dutch Masters, stylizing pictures in the style of <a href="https://qz.com/495614/computers-can-now-paint-like-van-gogh-and-picasso/">Van Gogh and Picasso</a>, and so on. At the time, there was more concern about the future of human creativity: would we still need artists? Would we live in a world full of fake Van Goghs? We shrugged those “fakes” off because we were asking the wrong questions. We don’t need more Van Goghs any more than we need more <a href="https://en.wikipedia.org/wiki/Velvet_Elvis">Elvises on velvet</a>. We may end up with a few fake Rembrandts where they shouldn’t be, but the art world will survive.</p>\n\n\n\n<p>If that’s the wrong question, what’s the right one? The problem with deepfakes is that simulating an artist’s style collided with the rise of fake news. Fake news isn’t new by any means; there have always been conspiracy theorists who are marvelously skeptical of “traditional” media, but are completely unskeptical of their own sources, whether they claim that Tibetans are spying on us through a system of underground tunnels or that vaccinations cause autism.</p>\n\n\n\n<p>To this collision, add three more factors: the democratization of AI, the decrease in the cost of computing power, and the phenomenon of virality. Deepfakes jumped out of the lab and into the streets. You don’t need a Ph.D. to generate fake media, nor do you need the resources of a nation state to acquire enough computing power. Some easily available tools and a credit card to buy time on AWS are all you need. In some cases, it only takes an app: in China, a popular iPhone app <a href="https://www.theverge.com/2019/9/2/20844338/zao-deepfake-app-movie-tv-show-face-replace-privacy-policy-concerns">lets you put your face into movie clips</a>. (Ironically, backlash against this app didn’t take place because of the fakes but because of the app’s privacy policy.) Once you’ve created a fake, you can use social media to propagate it. YouTube’s and Facebook’s algorithms for optimizing “engagement” can make any content viral in seconds.</p>\n\n\n\n<p>That all adds up to a scary picture. We will certainly see deepfakes in politics, though as security expert @thegrugq <a href="https://medium.com/@thegrugq/cheap-fakes-beat-deep-fakes-b1ac91e44837">points out</a>, cheap fakes are better than deepfakes for shaping public opinion. Deepfakes might be more dangerous in computer security, where they can be used to circumvent authentication or perform high-quality phishing attacks. Symantec <a href="https://www.ft.com/content/63cd4010-bfce-11e9-b350-db00d509634e">has reported</a> that it has seen such attacks in the field, and recently an <a href="https://beta.washingtonpost.com/technology/2019/09/04/an-artificial-intelligence-first-voice-mimicking ...
#    'feedburner_origlink': 'https://www.oreilly.com/radar/a-world-of-deepfakes/',
#    'guidislink': False,
#    'id': 'https://www.oreilly.com/radar/?p=10617',
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9PQAmHRa6oA/',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9PQAmHRa6oA/',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'published': 'Thu, 07 Nov 2019 14:00:50 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=14, tm_min=0, tm_sec=50, tm_wday=3, tm_yday=311, tm_isdst=0),
#    'slash_comments': '0',
#    'summary': 'Deepfakes have been very much in the news for the past two years. It’s time to think about what deepfakes are and what they mean. Where do they come from? Why now? Is this just a natural evolution in the history of technology? Deepfakes are media that are created by AI. They appear to be [&#8230;]',
#    'summary_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/html',
#     'value': 'Deepfakes have been very much in the news for the past two years. It’s time to think about what deepfakes are and what they mean. Where do they come from? Why now? Is this just a natural evolution in the history of technology? Deepfakes are media that are created by AI. They appear to be [&#8230;]'},
#    'tags': [{'label': None, 'scheme': None, 'term': 'AI & ML'},
#     {'label': None, 'scheme': None, 'term': 'Deep Dive'}],
#    'title': 'A world of deepfakes',
#    'title_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/plain',
#     'value': 'A world of deepfakes'},
#    'wfw_commentrss': 'https://www.oreilly.com/radar/a-world-of-deepfakes/feed/'},
#   {'author': 'Mike Loukides',
#    'author_detail': {'name': 'Mike Loukides'},
#    'authors': [{'name': 'Mike Loukides'}],
#    'comments': 'https://www.oreilly.com/radar/radar-trends-to-watch-november-2019/#respond',
#    'content': [{'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'language': None,
#      'type': 'text/html',
#      'value': '<h2>5G trends</h2>\n\n\n\n<p><a href="https://www.tomsguide.com/us/5g-release-date,review-5063.html">5G networks</a> get so much commentary that it’s almost hard to consider them a trend, especially since they’ve only started to roll out, and the 5G networks that currently exist are really nothing to get excited about. However, it’s important to be aware of changes in applications and application architectures. What happens if mobile platforms suddenly have gigabit-per-second network connections? What kinds of applications does that enable? At this point, we don’t really know. Gigabit connectivity to small, low-power devices will certainly make them more powerful. Will it enable a new generation of <a href="https://breakermag.com/the-decentralized-web-explained-in-words-you-can-understand/">decentralized web applications</a>? Perhaps, though those applications may depend more on latency than bandwidth. Pundits say that 5G will be essential for autonomous vehicles (but don’t tell me you’re going to get gigabit-per-second bandwidth when you’re driving through the Rockies in the snow). This is one of those “will change things in unexpected ways” technologies; we don’t yet know where it will lead, but it certainly will lead.</p>\n\n\n\n<h2>Device trends</h2>\n\n\n\n<p>Is <a href="https://www.forbes.com/sites/jasonevangelho/2019/10/18/meet-the-linux-desktop-that-will-blow-away-windows-10-and-macos-in-2020/">Deepin</a> a Linux desktop we will want to use? The transition from PCs to MacBooks in 2001 happened quickly. Among software developers, frustration with Apple and macOS is high: laptops with <a href="https://www.cultofmac.com/637358/2019-macbook-air-pro-butterfly-keyboard-repair-service-program/">fragile keyboards</a> that don’t have an <a href="https://www.theverge.com/circuitbreaker/2016/10/25/13409258/apple-new-macbook-pro-no-escape-key">escape key</a>, <a href="https://www.macobserver.com/columns-opinions/editorial/two-ports-on-macbook-air-ridiculous/">minimal device connectivity</a>, and a <a href="https://www.techrepublic.com/article/why-macos-catalina-is-not-apples-finest-moment/">flawed</a> operating system that tries to trap you in Apple’s walled garden make a poor case for developer loyalty. I wouldn’t be surprised to see the kind of phase change that we saw in 2001 again. Could Linux be the winner? I’m skeptical about Linux desktops, but a dark horse might win this race.<br></p>\n\n\n\n<p>Another possibility for the post-MacBook laptop is the <a href="https://www.tomsguide.com/news/microsoft-has-beaten-apple">Microsoft Surface</a>. It’s a very nice machine. However, Microsoft seems to be having its <a href="https://www.forbes.com/sites/gordonkelly/2019/10/05/microsoft-windows-10-warning-search-start-menu-bootprint-problem-upgrade-windows-10/#659df1c450c1">own woes with Windows 10</a>, which may make it a poor alternative to macOS.<br></p>\n\n\n\n<p>Google is taking on <a href="https://www.theverge.com/2019/10/16/20917096/nest-google-privacy-security-smart-home-cambridge-analytica-works-with">home IoT security</a> with tighter restrictions and auditing requirements for how third-party partners can use data with its Nest devices. This will present problems for companies that interoperate with Nest because it will limit their access to customer data. At the same time, it’s ironic, given Google’s own issues with customer data—specifically, <a href="https://www.cnet.com/how-to/amazon-and-google-are-listening-to-your-voice-recordings-heres-what-we-know/">conversations recorded by Google Home</a> and newly discovered <a href="https://www.theverge.com/2019/10/21/20924886/alexa-google-home-security-vulnerability-srlabs-phishing-eavesdropping">vulnerabilities</a> in Google Assistant (and Alexa).<br></p>\n\n\n\n<h2>Augmented reality trends</h2>\n\n\n\n<p><a href="https://www.tomsguide.com/news/apples-ar-glasses-set-for-2020-launch-says-top-analyst">Apple Glasses</a> is apparently real and will reportedly launch i ...
#    'feedburner_origlink': 'https://www.oreilly.com/radar/radar-trends-to-watch-november-2019/',
#    'guidislink': False,
#    'id': 'https://www.oreilly.com/radar/?p=10365',
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/CbEHmAz1wbI/',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/CbEHmAz1wbI/',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'published': 'Thu, 07 Nov 2019 05:10:11 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=5, tm_min=10, tm_sec=11, tm_wday=3, tm_yday=311, tm_isdst=0),
#    'slash_comments': '0',
#    'summary': '5G trends 5G networks get so much commentary that it’s almost hard to consider them a trend, especially since they’ve only started to roll out, and the 5G networks that currently exist are really nothing to get excited about. However, it’s important to be aware of changes in applications and application architectures. What happens if [&#8230;]',
#    'summary_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/html',
#     'value': '5G trends 5G networks get so much commentary that it’s almost hard to consider them a trend, especially since they’ve only started to roll out, and the 5G networks that currently exist are really nothing to get excited about. However, it’s important to be aware of changes in applications and application architectures. What happens if [&#8230;]'},
#    'tags': [{'label': None, 'scheme': None, 'term': 'Radar Trends'},
#     {'label': None, 'scheme': None, 'term': 'Signals'}],
#    'title': 'Radar trends to watch: November 2019',
#    'title_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/plain',
#     'value': 'Radar trends to watch: November 2019'},
#    'wfw_commentrss': 'https://www.oreilly.com/radar/radar-trends-to-watch-november-2019/feed/'},
#   {'author': 'Nat Torkington',
#    'author_detail': {'name': 'Nat Torkington'},
#    'authors': [{'name': 'Nat Torkington'}],
#    'comments': 'https://www.oreilly.com/radar/four-short-links-7-november-2019/#respond',
#    'content': [{'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'language': None,
#      'type': 'text/html',
# ...
#      'language': None,
#      'type': 'text/html',
#      'value': '<p>This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. <a href="https://learning.oreilly.com/videos/oreilly-software-architecture/9781492050728/9781492050728-video328590">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-software-architecture-berlin-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/Yt4AXIfTQUA" height="1" width="1" alt=""/>'}],
#    'feedburner_origlink': 'https://www.oreilly.com/radar/modern-machine-learning-architectures/',
#    'guidislink': False,
#    'id': 'https://www.oreilly.com/radar/?p=10473',
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/Yt4AXIfTQUA/',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/Yt4AXIfTQUA/',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'published': 'Wed, 06 Nov 2019 18:40:13 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=6, tm_hour=18, tm_min=40, tm_sec=13, tm_wday=2, tm_yday=310, tm_isdst=0),
#    'slash_comments': '0',
#    'summary': 'This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#    'summary_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/html',
#     'value': 'This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#    'tags': [{'label': None, 'scheme': None, 'term': 'Next Architecture'},
#     {'label': None,
#      'scheme': None,
#      'term': 'Software Architecture Berlin 2019'}],
#    'title': 'Modern machine learning architectures: Data and hardware and platform, oh my',
#    'title_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/plain',
#     'value': 'Modern machine learning architectures: Data and hardware and platform, oh my'},
#    'wfw_commentrss': 'https://www.oreilly.com/radar/modern-machine-learning-architectures/feed/'},
#   {'author': 'Cheryl Hung',
#    'author_detail': {'name': 'Cheryl Hung'},
#    'authors': [{'name': 'Cheryl Hung'}],
#    'comments': 'https://www.oreilly.com/radar/the-new-norms-of-cloud-native/#respond',
#    'content': [{'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'language': None,
#      'type': 'text/html',
#      'value': '<p>This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. <a href="https://learning.oreilly.com/videos/oreilly-software-architecture/9781492050728/9781492050728-video328583">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-software-architecture-berlin-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/38WIXuEtqwc" height="1" width="1" alt=""/>'}],
#    'feedburner_origlink': 'https://www.oreilly.com/radar/the-new-norms-of-cloud-native/',
#    'guidislink': False,
#    'id': 'https://www.oreilly.com/radar/?p=10484',
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/38WIXuEtqwc/',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/38WIXuEtqwc/',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'published': 'Wed, 06 Nov 2019 18:40:10 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=6, tm_hour=18, tm_min=40, tm_sec=10, tm_wday=2, tm_yday=310, tm_isdst=0),
#    'slash_comments': '0',
#    'summary': 'This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#    'summary_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/html',
#     'value': 'This is a keynote highlight from the O&#8217;Reilly Software Architecture Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#    'tags': [{'label': None, 'scheme': None, 'term': 'Next Architecture'},
#     {'label': None,
#      'scheme': None,
#      'term': 'Software Architecture Berlin 2019'}],
#    'title': 'The new norms of cloud native',
#    'title_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/plain',
#     'value': 'The new norms of cloud native'},
#    'wfw_commentrss': 'https://www.oreilly.com/radar/the-new-norms-of-cloud-native/feed/'},
#   {'author': 'Christine Yen',
#    'author_detail': {'name': 'Christine Yen'},
#    'authors': [{'name': 'Christine Yen'}],
#    'comments': 'https://www.oreilly.com/radar/observability-understanding-production-through-your-customers-eyes/#respond',
#    'content': [{'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'language': None,
#      'type': 'text/html',
#      'value': '<p>This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. <a href="https://learning.oreilly.com/videos/oreilly-velocity-conference/9781492050742/9781492050742-video328474">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-velocity-berlin-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/dwuKJeChqKw" height="1" width="1" alt=""/>'}],
#    'feedburner_origlink': 'https://www.oreilly.com/radar/observability-understanding-production-through-your-customers-eyes/',
#    'guidislink': False,
#    'id': 'https://www.oreilly.com/radar/?p=10517',
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/dwuKJeChqKw/',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/dwuKJeChqKw/',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'published': 'Wed, 06 Nov 2019 18:30:32 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=6, tm_hour=18, tm_min=30, tm_sec=32, tm_wday=2, tm_yday=310, tm_isdst=0),
#    'slash_comments': '0',
#    'summary': 'This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#    'summary_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/html',
#     'value': 'This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#    'tags': [{'label': None, 'scheme': None, 'term': 'Next Architecture'},
#     {'label': None,
#      'scheme': None,
#      'term': 'Velocity Conference Berlin 2019'}],
#    'title': 'Observability: Understanding production through your customers’ eyes',
#    'title_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/plain',
#     'value': 'Observability: Understanding production through your customers’ eyes'},
#    'wfw_commentrss': 'https://www.oreilly.com/radar/observability-understanding-production-through-your-customers-eyes/feed/'},
#   {'author': 'Ana Oprea',
#    'author_detail': {'name': 'Ana Oprea'},
#    'authors': [{'name': 'Ana Oprea'}],
#    'comments': 'https://www.oreilly.com/radar/secure-reliable-systems-velocity-eu-19/#respond',
#    'content': [{'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'language': None,
#      'type': 'text/html',
#      'value': '<p>This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. <a href="https://learning.oreilly.com/videos/oreilly-velocity-conference/9781492050742/9781492050742-video328392">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-velocity-berlin-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/v_dKWebs3tE" height="1" width="1" alt=""/>'}],
#    'feedburner_origlink': 'https://www.oreilly.com/radar/secure-reliable-systems-velocity-eu-19/',
#    'guidislink': False,
#    'id': 'https://www.oreilly.com/radar/?p=10524',
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/v_dKWebs3tE/',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/v_dKWebs3tE/',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'published': 'Wed, 06 Nov 2019 18:30:29 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=6, tm_hour=18, tm_min=30, tm_sec=29, tm_wday=2, tm_yday=310, tm_isdst=0),
#    'slash_comments': '0',
#    'summary': 'This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#    'summary_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/html',
#     'value': 'This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#    'tags': [{'label': None, 'scheme': None, 'term': 'Next Architecture'},
#     {'label': None,
#      'scheme': None,
#      'term': 'Velocity Conference Berlin 2019'}],
#    'title': 'Secure reliable systems',
#    'title_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/plain',
#     'value': 'Secure reliable systems'},
#    'wfw_commentrss': 'https://www.oreilly.com/radar/secure-reliable-systems-velocity-eu-19/feed/'},
#   {'author': 'James Mickens',
#    'author_detail': {'name': 'James Mickens'},
#    'authors': [{'name': 'James Mickens'}],
#    'comments': 'https://www.oreilly.com/radar/my-love-letter-to-computer-science-is-very-short/#respond',
#    'content': [{'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'language': None,
#      'type': 'text/html',
#      'value': '<p>This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. <a href="https://learning.oreilly.com/videos/oreilly-velocity-conference/9781492050742/9781492050742-video328472">Watch the full version of this keynote on the O&#8217;Reilly online learning platform</a>.</p>\n<p>You can also <a href="https://www.oreilly.com/radar/highlights-from-velocity-berlin-2019">see other highlights from the event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/ZCwrHetWTBo" height="1" width="1" alt=""/>'}],
#    'feedburner_origlink': 'https://www.oreilly.com/radar/my-love-letter-to-computer-science-is-very-short/',
#    'guidislink': False,
#    'id': 'https://www.oreilly.com/radar/?p=10510',
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/ZCwrHetWTBo/',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/ZCwrHetWTBo/',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'published': 'Wed, 06 Nov 2019 18:30:20 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=6, tm_hour=18, tm_min=30, tm_sec=20, tm_wday=2, tm_yday=310, tm_isdst=0),
#    'slash_comments': '0',
#    'summary': 'This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.',
#    'summary_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/html',
#     'value': 'This is a keynote highlight from the O&#8217;Reilly Velocity Conference in Berlin 2019. Watch the full version of this keynote on the O&#8217;Reilly online learning platform. You can also see other highlights from the event.'},
#    'tags': [{'label': None, 'scheme': None, 'term': 'Next Architecture'},
#     {'label': None,
#      'scheme': None,
#      'term': 'Velocity Conference Berlin 2019'}],
#    'title': 'My love letter to computer science is very short and I also forgot to mail it',
#    'title_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'language': None,
#     'type': 'text/plain',
#     'value': 'My love letter to computer science is very short and I also forgot to mail it'},
#    'wfw_commentrss': 'https://www.oreilly.com/radar/my-love-letter-to-computer-science-is-very-short/feed/'}],
#  'etag': '2OFBvdLtT9x/2AOasqtC0aZ4dfo',
#  'feed': {'feedburner_emailserviceid': 'oreilly/radar/atom',
#   'feedburner_feedburnerhostname': 'https://feedburner.google.com',
#   'feedburner_info': {'uri': 'oreilly/radar/atom'},
#   'generator': 'https://wordpress.org/?v=5.2.4',
#   'generator_detail': {'name': 'https://wordpress.org/?v=5.2.4'},
#   'geo_lat': '38.393314',
#   'geo_long': '-122.836667',
#   'language': 'en-US',
#   'link': 'https://www.oreilly.com/radar',
#   'links': [{'href': 'https://www.oreilly.com/radar',
#     'rel': 'alternate',
#     'type': 'text/html'},
#    {'href': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'rel': 'self',
#     'type': 'application/rss+xml'},
#    {'href': 'http://pubsubhubbub.appspot.com/',
#     'rel': 'hub',
#     'type': 'text/html'}],
#   'subtitle': 'Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology',
#   'subtitle_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'language': None,
#    'type': 'text/html',
#    'value': 'Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology'},
#   'sy_updatefrequency': '1',
#   'sy_updateperiod': 'hourly',
#   'title': 'Radar',
#   'title_detail': {'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Radar'},
#   'updated': 'Thu, 07 Nov 2019 21:22:44 +0000',
#   'updated_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=21, tm_min=22, tm_sec=44, tm_wday=3, tm_yday=311, tm_isdst=0)},
#  'headers': {'Cache-Control': 'private, max-age=0',
#   'Connection': 'close',
#   'Content-Encoding': 'gzip',
#   'Content-Type': 'text/xml; charset=UTF-8',
#   'Date': 'Fri, 08 Nov 2019 00:55:17 GMT',
#   'ETag': '2OFBvdLtT9x/2AOasqtC0aZ4dfo',
#   'Expires': 'Fri, 08 Nov 2019 00:55:17 GMT',
#   'Last-Modified': 'Thu, 07 Nov 2019 23:53:41 GMT',
#   'Server': 'GSE',
#   'Transfer-Encoding': 'chunked',
#   'X-Content-Type-Options': 'nosniff',
#   'X-XSS-Protection': '1; mode=block'},
#  'href': 'http://feeds.feedburner.com/oreilly/radar/atom',
#  'namespaces': {'': 'http://www.w3.org/2005/Atom',
#   'content': 'http://purl.org/rss/1.0/modules/content/',
#   'dc': 'http://purl.org/dc/elements/1.1/',
#   'feedburner': 'http://rssnamespace.org/feedburner/ext/1.0',
#   'geo': 'http://www.w3.org/2003/01/geo/wgs84_pos#',
#   'slash': 'http://purl.org/rss/1.0/modules/slash/',
#   'sy': 'http://purl.org/rss/1.0/modules/syndication/',
#   'wfw': 'http://wellformedweb.org/CommentAPI/'},
#  'status': 200,
#  'updated': 'Thu, 07 Nov 2019 23:53:41 GMT',
#  'updated_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=7, tm_hour=23, tm_min=53, tm_sec=41, tm_wday=3, tm_yday=311, tm_isdst=0),
#  'version': 'rss20'}

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
burner.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'etag', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
burner.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'subtitle', 'subtitle_detail', 'updated', 'updated_parsed', 'language', 'sy_updateperiod', 'sy_updatefrequency', 'generator_detail', 'generator', 'feedburner_info', 'geo_lat', 'geo_long', 'feedburner_emailserviceid', 'feedburner_feedburnerhostname'])

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
print (burner.feed.title)
print ('')
print (burner.feed.subtitle)
print ('')
print (burner.entries[0]['author'])
print ('')
print (burner.feed.link)
# Out:
# Radar
#
# Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology
#
# Mac Slocum
#
# https://www.oreilly.com/radar

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
len(burner.entries)
# Out:
# 18

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
burner.entries[0].keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'comments', 'published', 'published_parsed', 'authors', 'author', 'author_detail', 'tags', 'id', 'guidislink', 'summary', 'summary_detail', 'content', 'wfw_commentrss', 'slash_comments', 'feedburner_origlink'])

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
titles = [burner.entries[i].title for i in range(len(burner.entries))]
print(titles)
# Out:
# ['Highlights from the O’Reilly Software Architecture Conference in Berlin 2019', 'Highlights from the O’Reilly Velocity Conference in Berlin 2019', 'From the trenches: Patrick Kua', '5 things Go taught me about open source?', 'Building high-performing engineering teams, one pixel at a time', 'How to deploy infrastructure in just 13.8 billion years', 'Controlled chaos: The inevitable marriage of DevOps and security', 'The ultimate guide to complicated systems', 'Cognitive biases in the architect’s life', 'The three-headed dog: Architecture, process, structure', 'A world of deepfakes', 'Radar trends to watch: November 2019', 'Four short links: 7 November 2019', 'Modern machine learning architectures: Data and hardware and platform, oh my', 'The new norms of cloud native', 'Observability: Understanding production through your customers’ eyes', 'Secure reliable systems', 'My love letter to computer science is very short and I also forgot to mail it']

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
def percentaje(tit):
    contar = 0
    for i in titles:
        if title == i:
            contar += 1
    percentage = contar/len(titles)
    return percentage

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd

# %%
df = pd.DataFrame(burner.entries)
df
# Out:
#                           author                             author_detail  \
# 0                     Mac Slocum                    {'name': 'Mac Slocum'}
# 1                     Mac Slocum                    {'name': 'Mac Slocum'}
# 2      Patrick Kua and Neal Ford     {'name': 'Patrick Kua and Neal Ford'}
# 3                    Dave Cheney                   {'name': 'Dave Cheney'}
# 4                  Lena Reinhard                 {'name': 'Lena Reinhard'}
# 5              Ingrid Burrington             {'name': 'Ingrid Burrington'}
# 6               Kelly Shortridge              {'name': 'Kelly Shortridge'}
# 7                 Jennifer Davis                {'name': 'Jennifer Davis'}
# 8             Birgitta Boeckeler            {'name': 'Birgitta Boeckeler'}
# 9                    Allen Holub                   {'name': 'Allen Holub'}
# 10  Ben Lorica and Mike Loukides  {'name': 'Ben Lorica and Mike Loukides'}
# 11                 Mike Loukides                 {'name': 'Mike Loukides'}
# 12                Nat Torkington                {'name': 'Nat Torkington'}
# 13                 Brian Sletten                 {'name': 'Brian Sletten'}
# 14                   Cheryl Hung                   {'name': 'Cheryl Hung'}
# 15                 Christine Yen                 {'name': 'Christine Yen'}
# 16                     Ana Oprea                     {'name': 'Ana Oprea'}
# 17                 James Mickens                 {'name': 'James Mickens'}
#
#                                        authors  \
# 0                     [{'name': 'Mac Slocum'}]
# 1                     [{'name': 'Mac Slocum'}]
# 2      [{'name': 'Patrick Kua and Neal Ford'}]
# 3                    [{'name': 'Dave Cheney'}]
# 4                  [{'name': 'Lena Reinhard'}]
# 5              [{'name': 'Ingrid Burrington'}]
# 6               [{'name': 'Kelly Shortridge'}]
# 7                 [{'name': 'Jennifer Davis'}]
# 8             [{'name': 'Birgitta Boeckeler'}]
# 9                    [{'name': 'Allen Holub'}]
# 10  [{'name': 'Ben Lorica and Mike Loukides'}]
# 11                 [{'name': 'Mike Loukides'}]
# 12                [{'name': 'Nat Torkington'}]
# 13                 [{'name': 'Brian Sletten'}]
# 14                   [{'name': 'Cheryl Hung'}]
# 15                 [{'name': 'Christine Yen'}]
# 16                     [{'name': 'Ana Oprea'}]
# 17                 [{'name': 'James Mickens'}]
#
#                                              comments  \
# 0   https://www.oreilly.com/radar/highlights-from-...
# 1   https://www.oreilly.com/radar/highlights-from-...
# 2   https://www.oreilly.com/radar/from-the-trenche...
# 3   https://www.oreilly.com/radar/5-things-go-taug...
# 4   https://www.oreilly.com/radar/building-high-pe...
# 5   https://www.oreilly.com/radar/how-to-deploy-in...
# 6   https://www.oreilly.com/radar/controlled-chaos...
# 7   https://www.oreilly.com/radar/the-ultimate-gui...
# 8   https://www.oreilly.com/radar/cognitive-biases...
# 9   https://www.oreilly.com/radar/the-three-headed...
# 10  https://www.oreilly.com/radar/a-world-of-deepf...
# 11  https://www.oreilly.com/radar/radar-trends-to-...
# 12  https://www.oreilly.com/radar/four-short-links...
# 13  https://www.oreilly.com/radar/modern-machine-l...
# 14  https://www.oreilly.com/radar/the-new-norms-of...
# 15  https://www.oreilly.com/radar/observability-un...
# 16  https://www.oreilly.com/radar/secure-reliable-...
# 17  https://www.oreilly.com/radar/my-love-letter-t...
#
#                                               content  \
# 0   [{'type': 'text/html', 'language': None, 'base...
# 1   [{'type': 'text/html', 'language': None, 'base...
# 2   [{'type': 'text/html', 'language': None, 'base...
# 3   [{'type': 'text/html', 'language': None, 'base...
# 4   [{'type': 'text/html', 'language': None, 'base...
# 5   [{'type': 'text/html', 'language': None, 'base...
# 6   [{'type': 'text/html', 'language': None, 'base...
# 7   [{'type': 'text/html', 'language': None, 'base...
# 8   [{'type': 'text/html', 'language': None, 'base...
# 9   [{'type': 'text/html', 'language': None, 'base...
# 10  [{'type': 'text/html', 'language': None, 'base...
# 11  [{'type': 'text/html', 'language': None, 'base...
# 12  [{'type': 'text/html', 'language': None, 'base...
# 13  [{'type': 'text/html', 'language': None, 'base...
# 14  [{'type': 'text/html', 'language': None, 'base...
# 15  [{'type': 'text/html', 'language': None, 'base...
# 16  [{'type': 'text/html', 'language': None, 'base...
# 17  [{'type': 'text/html', 'language': None, 'base...
#
#                                   feedburner_origlink guidislink  \
# 0   https://www.oreilly.com/radar/highlights-from-...      False
# 1   https://www.oreilly.com/radar/highlights-from-...      False
# 2   https://www.oreilly.com/radar/from-the-trenche...      False
# 3   https://www.oreilly.com/radar/5-things-go-taug...      False
# 4   https://www.oreilly.com/radar/building-high-pe...      False
# 5   https://www.oreilly.com/radar/how-to-deploy-in...      False
# 6   https://www.oreilly.com/radar/controlled-chaos...      False
# 7   https://www.oreilly.com/radar/the-ultimate-gui...      False
# 8   https://www.oreilly.com/radar/cognitive-biases...      False
# 9   https://www.oreilly.com/radar/the-three-headed...      False
# 10  https://www.oreilly.com/radar/a-world-of-deepf...      False
# 11  https://www.oreilly.com/radar/radar-trends-to-...      False
# 12  https://www.oreilly.com/radar/four-short-links...      False
# 13  https://www.oreilly.com/radar/modern-machine-l...      False
# 14  https://www.oreilly.com/radar/the-new-norms-of...      False
# 15  https://www.oreilly.com/radar/observability-un...      False
# 16  https://www.oreilly.com/radar/secure-reliable-...      False
# 17  https://www.oreilly.com/radar/my-love-letter-t...      False
#
#                                         id  \
# 0   https://www.oreilly.com/radar/?p=10569
# 1   https://www.oreilly.com/radar/?p=10577
# 2   https://www.oreilly.com/radar/?p=10503
# 3   https://www.oreilly.com/radar/?p=10549
# 4   https://www.oreilly.com/radar/?p=10556
# 5   https://www.oreilly.com/radar/?p=10536
# 6   https://www.oreilly.com/radar/?p=10561
# 7   https://www.oreilly.com/radar/?p=10540
# 8   https://www.oreilly.com/radar/?p=10497
# 9   https://www.oreilly.com/radar/?p=10490
# 10  https://www.oreilly.com/radar/?p=10617
# 11  https://www.oreilly.com/radar/?p=10365
# 12  https://www.oreilly.com/radar/?p=10731
# 13  https://www.oreilly.com/radar/?p=10473
# 14  https://www.oreilly.com/radar/?p=10484
# 15  https://www.oreilly.com/radar/?p=10517
# 16  https://www.oreilly.com/radar/?p=10524
# 17  https://www.oreilly.com/radar/?p=10510
#
#                                                  link  \
# 0   http://feedproxy.google.com/~r/oreilly/radar/a...
# 1   http://feedproxy.google.com/~r/oreilly/radar/a...
# 2   http://feedproxy.google.com/~r/oreilly/radar/a...
# 3   http://feedproxy.google.com/~r/oreilly/radar/a...
# 4   http://feedproxy.google.com/~r/oreilly/radar/a...
# 5   http://feedproxy.google.com/~r/oreilly/radar/a...
# 6   http://feedproxy.google.com/~r/oreilly/radar/a...
# 7   http://feedproxy.google.com/~r/oreilly/radar/a...
# 8   http://feedproxy.google.com/~r/oreilly/radar/a...
# 9   http://feedproxy.google.com/~r/oreilly/radar/a...
# 10  http://feedproxy.google.com/~r/oreilly/radar/a...
# 11  http://feedproxy.google.com/~r/oreilly/radar/a...
# 12  http://feedproxy.google.com/~r/oreilly/radar/a...
# 13  http://feedproxy.google.com/~r/oreilly/radar/a...
# 14  http://feedproxy.google.com/~r/oreilly/radar/a...
# 15  http://feedproxy.google.com/~r/oreilly/radar/a...
# 16  http://feedproxy.google.com/~r/oreilly/radar/a...
# 17  http://feedproxy.google.com/~r/oreilly/radar/a...
#
#                                                 links  \
# 0   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 2   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 3   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 4   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 5   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 6   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 7   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 8   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 9   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 10  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 11  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 12  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 13  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 14  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 15  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 16  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 17  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                           published                      published_parsed  \
# 0   Thu, 07 Nov 2019 20:10:44 +0000  (2019, 11, 7, 20, 10, 44, 3, 311, 0)
# 1   Thu, 07 Nov 2019 20:09:07 +0000    (2019, 11, 7, 20, 9, 7, 3, 311, 0)
# 2   Thu, 07 Nov 2019 20:00:48 +0000   (2019, 11, 7, 20, 0, 48, 3, 311, 0)
# 3   Thu, 07 Nov 2019 20:00:38 +0000   (2019, 11, 7, 20, 0, 38, 3, 311, 0)
# 4   Thu, 07 Nov 2019 20:00:35 +0000   (2019, 11, 7, 20, 0, 35, 3, 311, 0)
# 5   Thu, 07 Nov 2019 20:00:34 +0000   (2019, 11, 7, 20, 0, 34, 3, 311, 0)
# 6   Thu, 07 Nov 2019 20:00:30 +0000   (2019, 11, 7, 20, 0, 30, 3, 311, 0)
# 7   Thu, 07 Nov 2019 20:00:17 +0000   (2019, 11, 7, 20, 0, 17, 3, 311, 0)
# 8   Thu, 07 Nov 2019 20:00:07 +0000    (2019, 11, 7, 20, 0, 7, 3, 311, 0)
# 9   Thu, 07 Nov 2019 20:00:06 +0000    (2019, 11, 7, 20, 0, 6, 3, 311, 0)
# 10  Thu, 07 Nov 2019 14:00:50 +0000   (2019, 11, 7, 14, 0, 50, 3, 311, 0)
# 11  Thu, 07 Nov 2019 05:10:11 +0000   (2019, 11, 7, 5, 10, 11, 3, 311, 0)
# 12  Thu, 07 Nov 2019 05:01:24 +0000    (2019, 11, 7, 5, 1, 24, 3, 311, 0)
# 13  Wed, 06 Nov 2019 18:40:13 +0000  (2019, 11, 6, 18, 40, 13, 2, 310, 0)
# 14  Wed, 06 Nov 2019 18:40:10 +0000  (2019, 11, 6, 18, 40, 10, 2, 310, 0)
# 15  Wed, 06 Nov 2019 18:30:32 +0000  (2019, 11, 6, 18, 30, 32, 2, 310, 0)
# 16  Wed, 06 Nov 2019 18:30:29 +0000  (2019, 11, 6, 18, 30, 29, 2, 310, 0)
# 17  Wed, 06 Nov 2019 18:30:20 +0000  (2019, 11, 6, 18, 30, 20, 2, 310, 0)
#
#    slash_comments                                            summary  \
# 0               0  Experts from across the software architecture ...
# 1               0  People from across the cloud native and distri...
# 2               0  This is a keynote highlight from the O&#8217;R...
# 3               0  This is a keynote highlight from the O&#8217;R...
# 4               0  This is a keynote highlight from the O&#8217;R...
# 5               0  This is a keynote highlight from the O&#8217;R...
# 6               0  This is a keynote highlight from the O&#8217;R...
# 7               0  This is a keynote highlight from the O&#8217;R...
# 8               0  This is a keynote highlight from the O&#8217;R...
# 9               0  This is a keynote highlight from the O&#8217;R...
# 10              0  Deepfakes have been very much in the news for ...
# 11              0  5G trends 5G networks get so much commentary t...
# 12              0  DNS Wars &#8212; But perhaps the position make...
# 13              0  This is a keynote highlight from the O&#8217;R...
# 14              0  This is a keynote highlight from the O&#8217;R...
# 15              0  This is a keynote highlight from the O&#8217;R...
# 16              0  This is a keynote highlight from the O&#8217;R...
# 17              0  This is a keynote highlight from the O&#8217;R...
#
#                                        summary_detail  \
# 0   {'type': 'text/html', 'language': None, 'base'...
# 1   {'type': 'text/html', 'language': None, 'base'...
# 2   {'type': 'text/html', 'language': None, 'base'...
# 3   {'type': 'text/html', 'language': None, 'base'...
# 4   {'type': 'text/html', 'language': None, 'base'...
# 5   {'type': 'text/html', 'language': None, 'base'...
# 6   {'type': 'text/html', 'language': None, 'base'...
# 7   {'type': 'text/html', 'language': None, 'base'...
# 8   {'type': 'text/html', 'language': None, 'base'...
# 9   {'type': 'text/html', 'language': None, 'base'...
# 10  {'type': 'text/html', 'language': None, 'base'...
# 11  {'type': 'text/html', 'language': None, 'base'...
# 12  {'type': 'text/html', 'language': None, 'base'...
# 13  {'type': 'text/html', 'language': None, 'base'...
# 14  {'type': 'text/html', 'language': None, 'base'...
# 15  {'type': 'text/html', 'language': None, 'base'...
# 16  {'type': 'text/html', 'language': None, 'base'...
# 17  {'type': 'text/html', 'language': None, 'base'...
#
#                                                  tags  \
# 0   [{'term': 'Next Architecture', 'scheme': None,...
# 1   [{'term': 'Next Architecture', 'scheme': None,...
# 2   [{'term': 'Next Architecture', 'scheme': None,...
# 3   [{'term': 'Next Architecture', 'scheme': None,...
# 4   [{'term': 'Next Architecture', 'scheme': None,...
# 5   [{'term': 'Next Architecture', 'scheme': None,...
# 6   [{'term': 'Next Architecture', 'scheme': None,...
# 7   [{'term': 'Next Architecture', 'scheme': None,...
# 8   [{'term': 'Next Architecture', 'scheme': None,...
# 9   [{'term': 'Next Architecture', 'scheme': None,...
# 10  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 11  [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 12  [{'term': 'Four Short Links', 'scheme': None, ...
# 13  [{'term': 'Next Architecture', 'scheme': None,...
# 14  [{'term': 'Next Architecture', 'scheme': None,...
# 15  [{'term': 'Next Architecture', 'scheme': None,...
# 16  [{'term': 'Next Architecture', 'scheme': None,...
# 17  [{'term': 'Next Architecture', 'scheme': None,...
#
#                                                 title  \
# 0   Highlights from the O’Reilly Software Architec...
# 1   Highlights from the O’Reilly Velocity Conferen...
# 2                      From the trenches: Patrick Kua
# 3            5 things Go taught me about open source?
# 4   Building high-performing engineering teams, on...
# 5   How to deploy infrastructure in just 13.8 bill...
# 6   Controlled chaos: The inevitable marriage of D...
# 7           The ultimate guide to complicated systems
# 8            Cognitive biases in the architect’s life
# 9   The three-headed dog: Architecture, process, s...
# 10                               A world of deepfakes
# 11               Radar trends to watch: November 2019
# 12                  Four short links: 7 November 2019
# 13  Modern machine learning architectures: Data an...
# 14                      The new norms of cloud native
# 15  Observability: Understanding production throug...
# 16                            Secure reliable systems
# 17  My love letter to computer science is very sho...
#
#                                          title_detail  \
# 0   {'type': 'text/plain', 'language': None, 'base...
# 1   {'type': 'text/plain', 'language': None, 'base...
# 2   {'type': 'text/plain', 'language': None, 'base...
# 3   {'type': 'text/plain', 'language': None, 'base...
# 4   {'type': 'text/plain', 'language': None, 'base...
# 5   {'type': 'text/plain', 'language': None, 'base...
# 6   {'type': 'text/plain', 'language': None, 'base...
# 7   {'type': 'text/plain', 'language': None, 'base...
# 8   {'type': 'text/plain', 'language': None, 'base...
# 9   {'type': 'text/plain', 'language': None, 'base...
# 10  {'type': 'text/plain', 'language': None, 'base...
# 11  {'type': 'text/plain', 'language': None, 'base...
# 12  {'type': 'text/plain', 'language': None, 'base...
# 13  {'type': 'text/plain', 'language': None, 'base...
# 14  {'type': 'text/plain', 'language': None, 'base...
# 15  {'type': 'text/plain', 'language': None, 'base...
# 16  {'type': 'text/plain', 'language': None, 'base...
# 17  {'type': 'text/plain', 'language': None, 'base...
#
#                                        wfw_commentrss
# 0   https://www.oreilly.com/radar/highlights-from-...
# 1   https://www.oreilly.com/radar/highlights-from-...
# 2   https://www.oreilly.com/radar/from-the-trenche...
# 3   https://www.oreilly.com/radar/5-things-go-taug...
# 4   https://www.oreilly.com/radar/building-high-pe...
# 5   https://www.oreilly.com/radar/how-to-deploy-in...
# 6   https://www.oreilly.com/radar/controlled-chaos...
# 7   https://www.oreilly.com/radar/the-ultimate-gui...
# 8   https://www.oreilly.com/radar/cognitive-biases...
# 9   https://www.oreilly.com/radar/the-three-headed...
# 10  https://www.oreilly.com/radar/a-world-of-deepf...
# 11  https://www.oreilly.com/radar/radar-trends-to-...
# 12  https://www.oreilly.com/radar/four-short-links...
# 13  https://www.oreilly.com/radar/modern-machine-l...
# 14  https://www.oreilly.com/radar/the-new-norms-of...
# 15  https://www.oreilly.com/radar/observability-un...
# 16  https://www.oreilly.com/radar/secure-reliable-...
# 17  https://www.oreilly.com/radar/my-love-letter-t...

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
author = df.groupby('author',as_index = False).agg({'title':'count'})
author.columns = ['author','entries']
author.sort_values('entries',ascending = False)
# Out:
#                           author  entries
# 13                    Mac Slocum        2
# 0                    Allen Holub        1
# 9                  James Mickens        1
# 15                Nat Torkington        1
# 14                 Mike Loukides        1
# 12                 Lena Reinhard        1
# 11              Kelly Shortridge        1
# 10                Jennifer Davis        1
# 8              Ingrid Burrington        1
# 1                      Ana Oprea        1
# 7                    Dave Cheney        1
# 6                  Christine Yen        1
# 5                    Cheryl Hung        1
# 4                  Brian Sletten        1
# 3             Birgitta Boeckeler        1
# 2   Ben Lorica and Mike Loukides        1
# 16     Patrick Kua and Neal Ford        1

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
df['title_length'] = df['title'].apply(len)
df[['title', 'author', 'title_length']].sort_values('title_length', ascending=False).head()
# Out:
# 17    My love letter to computer science is very sho...
# 13    Modern machine learning architectures: Data an...
# 0     Highlights from the O’Reilly Software Architec...
# 15    Observability: Understanding production throug...
# 6     Controlled chaos: The inevitable marriage of D...
# 4     Building high-performing engineering teams, on...
# 1     Highlights from the O’Reilly Velocity Conferen...
# 5     How to deploy infrastructure in just 13.8 bill...
# 9     The three-headed dog: Architecture, process, s...
# 7             The ultimate guide to complicated systems
# 3              5 things Go taught me about open source?
# 8              Cognitive biases in the architect’s life
# 11                 Radar trends to watch: November 2019
# 12                    Four short links: 7 November 2019
# 2                        From the trenches: Patrick Kua
# 14                        The new norms of cloud native
# 16                              Secure reliable systems
# 10                                 A world of deepfakes
# Name: title, dtype: object

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
machine = [i for i in df['title'] if 'machine learning' in i]

# %%
machine
# Out:
# ['Modern machine learning architectures: Data and hardware and platform, oh my']
